# %% [markdown]
# <a href="https://colab.research.google.com/github/jacobpad/DS-Unit-2-Linear-Models/blob/master/module4-logistic-regression/LS_DS12_214A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 1, Module 4*
#
# ---

# %% [markdown]
# # Logistic Regression
#
#
#
# ---
#
#
# ## Assignment 🌯 ***CLASSIFICATION - A OR B - GREAT OR NOT***
#
#
# ---
#
#
# You'll use a [**dataset of 400+ burrito reviews**](https://srcole.github.io/100burritos/). How accurately can you predict whether a burrito is rated 'Great'?
#
# > We have developed a 10-dimensional system for rating the burritos in San Diego. ... Generate models for what makes a burrito great and investigate correlations in its dimensions.
#
# - [ ] Do train/validate/test split. Train on reviews from 2016 & earlier. Validate on 2017. Test on 2018 & later.
# - [ ] Begin with baselines for classification.
# - [ ] Use scikit-learn for logistic regression.
# - [ ] Get your model's validation accuracy. (Multiple times if you try multiple iterations.)
# - [ ] Get your model's test accuracy. (One time, at the end.)
# - [ ] Commit your notebook to your fork of the GitHub repo.
#
#
# ## Stretch Goals
#
# - [ ] Add your own stretch goal(s) !
# - [ ] Make exploratory visualizations.
# - [ ] Do one-hot encoding.
# - [ ] Do [feature scaling](https://scikit-learn.org/stable/modules/preprocessing.html).
# - [ ] Get and plot your coefficients.
# - [ ] Try [scikit-learn pipelines](https://scikit-learn.org/stable/modules/compose.html).

# %% [markdown]
# # This code was given to start with

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Linear-Models/master/data/'
    # !pip install category_encoders==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'

# %%
# Load data downloaded from https://srcole.github.io/100burritos/
import pandas as pd
df = pd.read_csv(DATA_PATH+'burritos/burritos.csv')

# %%
# Derive binary classification target:
# We define a 'Great' burrito as having an
# overall rating of 4 or higher, on a 5 point scale.
# Drop unrated burritos.
df = df.dropna(subset=['overall'])
df['Great'] = df['overall'] >= 4

# %%
# Clean/combine the Burrito categories
df['Burrito'] = df['Burrito'].str.lower()

california = df['Burrito'].str.contains('california')
asada = df['Burrito'].str.contains('asada')
surf = df['Burrito'].str.contains('surf')
carnitas = df['Burrito'].str.contains('carnitas')

df.loc[california, 'Burrito'] = 'California'
df.loc[asada, 'Burrito'] = 'Asada'
df.loc[surf, 'Burrito'] = 'Surf & Turf'
df.loc[carnitas, 'Burrito'] = 'Carnitas'
df.loc[~california & ~asada & ~surf & ~carnitas, 'Burrito'] = 'Other'

# %%
# Drop some high cardinality categoricals
df = df.drop(columns=['Notes', 'Location', 'Reviewer', 'Address', 'URL', 'Neighborhood'])

# %%
# Drop some columns to prevent "leakage"
df = df.drop(columns=['Rec', 'overall'])

# %% [markdown]
# # Start with my imports

# %%
# A bunch of imports, yes, it's probably overkill
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import math
import plotly.express as px
import category_encoders as ce
import datetime # import and manipulate datetime
from IPython.display import display, HTML
from warnings import filterwarnings
filterwarnings('ignore')
from sklearn.metrics import mean_absolute_error, r2_score, accuracy_score
from sklearn.linear_model import Ridge, LinearRegression, RidgeCV, LogisticRegressionCV
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
# Do train/validate/test split. Train on reviews from 2016 & earlier. Validate on 2017. Test on 2018 & later.
# Begin with baselines for classification.
# Use scikit-learn for logistic regression.
# Get your model's validation accuracy. (Multiple times if you try multiple iterations.)
# Get your model's test accuracy. (One time, at the end.)
# Commit your notebook to your fork of the GitHub repo.

# %% [markdown]
# # Check some things out

# %%
df.head()
# Out:
#       Burrito       Date  Yelp  Google Chips  ...  Sushi  Avocado  Corn  Zucchini  Great
# 0  California  1/18/2016   3.5     4.2   NaN  ...    NaN      NaN   NaN       NaN  False
# 1  California  1/24/2016   3.5     3.3   NaN  ...    NaN      NaN   NaN       NaN  False
# 2    Carnitas  1/24/2016   NaN     NaN   NaN  ...    NaN      NaN   NaN       NaN  False
# 3       Asada  1/24/2016   NaN     NaN   NaN  ...    NaN      NaN   NaN       NaN  False
# 4  California  1/27/2016   4.0     3.8     x  ...    NaN      NaN   NaN       NaN   True
#
# [5 rows x 59 columns]

# %%
df.describe()
# Out:
#             Yelp     Google        Cost  ...     Synergy        Wrap  Queso
# count  87.000000  87.000000  414.000000  ...  419.000000  418.000000    0.0
# mean    3.887356   4.167816    7.067343  ...    3.586993    3.979904    NaN
# std     0.475396   0.373698    1.506742  ...    0.886807    1.118185    NaN
# min     2.500000   2.900000    2.990000  ...    1.000000    0.000000    NaN
# 25%     3.500000   4.000000    6.250000  ...    3.000000    3.500000    NaN
# 50%     4.000000   4.200000    6.990000  ...    3.800000    4.000000    NaN
# 75%     4.000000   4.400000    7.880000  ...    4.000000    5.000000    NaN
# max     4.500000   5.000000   25.000000  ...    5.000000    5.000000    NaN
#
# [8 rows x 19 columns]

# %%
df.describe().T
# Out:
#                 count        mean  ...         75%         max
# Yelp             87.0    3.887356  ...    4.000000    4.500000
# Google           87.0    4.167816  ...    4.400000    5.000000
# Cost            414.0    7.067343  ...    7.880000   25.000000
# Hunger          418.0    3.495335  ...    4.000000    5.000000
# Mass (g)         22.0  546.181818  ...  595.000000  925.000000
# Density (g/mL)   22.0    0.675277  ...    0.721726    0.865672
# Length          283.0   20.038233  ...   21.500000   26.000000
# Circum          281.0   22.135765  ...   23.000000   29.000000
# Volume          281.0    0.786477  ...    0.880000    1.540000
# Tortilla        421.0    3.519477  ...    4.000000    5.000000
# Temp            401.0    3.783042  ...    4.500000    5.000000
# Meat            407.0    3.620393  ...    4.000000    5.000000
# Fillings        418.0    3.539833  ...    4.000000    5.000000
# Meat:filling    412.0    3.586481  ...    4.000000    5.000000
# Uniformity      419.0    3.428998  ...    4.000000    5.000000
# Salsa           396.0    3.371970  ...    4.000000    5.000000
# Synergy         419.0    3.586993  ...    4.000000    5.000000
# Wrap            418.0    3.979904  ...    5.000000    5.000000
# Queso             0.0         NaN  ...         NaN         NaN
#
# [19 rows x 8 columns]

# %%
df.describe(exclude='number')
# Out:
#            Burrito       Date Chips Unreliable  ... Avocado Corn Zucchini  Great
# count          421        421    26         33  ...      13    3        1    421
# unique           5        169     4          1  ...       1    2        1      2
# top     California  8/30/2016     x          x  ...       x    x        x  False
# freq           169         29    21         33  ...      13    2        1    239
#
# [4 rows x 40 columns]

# %%
df.describe(exclude='number').T
# Out:
#               count unique         top freq
# Burrito         421      5  California  169
# Date            421    169   8/30/2016   29
# Chips            26      4           x   21
# Unreliable       33      1           x   33
# NonSD             7      2           x    5
# Beef            179      2           x  137
# Pico            158      2           x  127
# Guac            154      2           x  114
# Cheese          159      2           x  128
# Fries           127      2           x  102
# Sour cream       92      2           x   67
# Pork             51      2           x   36
# Chicken          21      2           x   20
# Shrimp           21      2           x   17
# Fish              6      2           x    4
# Rice             36      2           x   26
# Beans            35      2           x   27
# Lettuce          11      2           x    9
# Tomato            7      2           x    5
# Bell peper        7      2           x    4
# Carrots           1      1           x    1
# Cabbage           8      2           x    6
# Sauce            38      2           x   33
# Salsa.1           7      2           x    6
# Cilantro         15      2           x    9
# Onion            17      2           x    9
# Taquito           4      2           x    3
# Pineapple         7      2           x    5
# Ham               2      1           x    2
# Chile relleno     4      1           x    4
# Nopales           4      1           x    4
# Lobster           1      1           x    1
# Egg               5      1           x    5
# Mushroom          3      1           x    3
# Bacon             3      1           x    3
# Sushi             2      1           x    2
# Avocado          13      1           x   13
# Corn              3      2           x    2
# Zucchini          1      1           x    1
# Great           421      2       False  239

# %%
df.columns
# Out:
# Index(['Burrito', 'Date', 'Yelp', 'Google', 'Chips', 'Cost', 'Hunger',
#        'Mass (g)', 'Density (g/mL)', 'Length', 'Circum', 'Volume', 'Tortilla',
#        'Temp', 'Meat', 'Fillings', 'Meat:filling', 'Uniformity', 'Salsa',
#        'Synergy', 'Wrap', 'Unreliable', 'NonSD', 'Beef', 'Pico', 'Guac',
#        'Cheese', 'Fries', 'Sour cream', 'Pork', 'Chicken', 'Shrimp', 'Fish',
#        'Rice', 'Beans', 'Lettuce', 'Tomato', 'Bell peper', 'Carrots',
#        'Cabbage', 'Sauce', 'Salsa.1', 'Cilantro', 'Onion', 'Taquito',
#        'Pineapple', 'Ham', 'Chile relleno', 'Nopales', 'Lobster', 'Queso',
#        'Egg', 'Mushroom', 'Bacon', 'Sushi', 'Avocado', 'Corn', 'Zucchini',
#        'Great'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Burrito             0
# Date                0
# Yelp              334
# Google            334
# Chips             395
# Cost                7
# Hunger              3
# Mass (g)          399
# Density (g/mL)    399
# Length            138
# Circum            140
# Volume            140
# Tortilla            0
# Temp               20
# Meat               14
# Fillings            3
# Meat:filling        9
# Uniformity          2
# Salsa              25
# Synergy             2
# Wrap                3
# Unreliable        388
# NonSD             414
# Beef              242
# Pico              263
# Guac              267
# Cheese            262
# Fries             294
# Sour cream        329
# Pork              370
# Chicken           400
# Shrimp            400
# Fish              415
# Rice              385
# Beans             386
# Lettuce           410
# Tomato            414
# Bell peper        414
# Carrots           420
# Cabbage           413
# Sauce             383
# Salsa.1           414
# Cilantro          406
# Onion             404
# Taquito           417
# Pineapple         414
# Ham               419
# Chile relleno     417
# Nopales           417
# Lobster           420
# Queso             421
# Egg               416
# Mushroom          418
# Bacon             418
# Sushi             419
# Avocado           408
# Corn              418
# Zucchini          420
# Great               0
# dtype: int64

# %%
# df.isnull().any()

# %%
df.describe(include='all')
# Out:
#            Burrito       Date       Yelp  ...  Corn Zucchini  Great
# count          421        421  87.000000  ...     3        1    421
# unique           5        169        NaN  ...     2        1      2
# top     California  8/30/2016        NaN  ...     x        x  False
# freq           169         29        NaN  ...     2        1    239
# mean           NaN        NaN   3.887356  ...   NaN      NaN    NaN
# std            NaN        NaN   0.475396  ...   NaN      NaN    NaN
# min            NaN        NaN   2.500000  ...   NaN      NaN    NaN
# 25%            NaN        NaN   3.500000  ...   NaN      NaN    NaN
# 50%            NaN        NaN   4.000000  ...   NaN      NaN    NaN
# 75%            NaN        NaN   4.000000  ...   NaN      NaN    NaN
# max            NaN        NaN   4.500000  ...   NaN      NaN    NaN
#
# [11 rows x 59 columns]

# %%
df.dtypes
# Out:
# Burrito            object
# Date               object
# Yelp              float64
# Google            float64
# Chips              object
# Cost              float64
# Hunger            float64
# Mass (g)          float64
# Density (g/mL)    float64
# Length            float64
# Circum            float64
# Volume            float64
# Tortilla          float64
# Temp              float64
# Meat              float64
# Fillings          float64
# Meat:filling      float64
# Uniformity        float64
# Salsa             float64
# Synergy           float64
# Wrap              float64
# Unreliable         object
# NonSD              object
# Beef               object
# Pico               object
# Guac               object
# Cheese             object
# Fries              object
# Sour cream         object
# Pork               object
# Chicken            object
# Shrimp             object
# Fish               object
# Rice               object
# Beans              object
# Lettuce            object
# Tomato             object
# Bell peper         object
# Carrots            object
# Cabbage            object
# Sauce              object
# Salsa.1            object
# Cilantro           object
# Onion              object
# Taquito            object
# Pineapple          object
# Ham                object
# Chile relleno      object
# Nopales            object
# Lobster            object
# Queso             float64
# Egg                object
# Mushroom           object
# Bacon              object
# Sushi              object
# Avocado            object
# Corn               object
# Zucchini           object
# Great                bool
# dtype: object

# %%
# Sum Null values by column and sort from least to greatest
# but first change the display
pd.set_option('display.max_rows', 60)
df.isnull().sum().sort_values()
# Out:
# Burrito             0
# Tortilla            0
# Great               0
# Date                0
# Synergy             2
# Uniformity          2
# Hunger              3
# Wrap                3
# Fillings            3
# Cost                7
# Meat:filling        9
# Meat               14
# Temp               20
# Salsa              25
# Length            138
# Circum            140
# Volume            140
# Beef              242
# Cheese            262
# Pico              263
# Guac              267
# Fries             294
# Sour cream        329
# Yelp              334
# Google            334
# Pork              370
# Sauce             383
# Rice              385
# Beans             386
# Unreliable        388
# Chips             395
# Density (g/mL)    399
# Mass (g)          399
# Chicken           400
# Shrimp            400
# Onion             404
# Cilantro          406
# Avocado           408
# Lettuce           410
# Cabbage           413
# Bell peper        414
# Salsa.1           414
# NonSD             414
# Pineapple         414
# Tomato            414
# Fish              415
# Egg               416
# Nopales           417
# Chile relleno     417
# Taquito           417
# Mushroom          418
# Bacon             418
# Corn              418
# Sushi             419
# Ham               419
# Lobster           420
# Zucchini          420
# Carrots           420
# Queso             421
# dtype: int64

# %%
df.shape
# Out:
# (421, 59)

# %%
df['Queso'].value_counts().sum()
# Out:
# 0

# %%
df['Queso'].sort_values().unique()
# Out:
# array([nan])

# %%
df['Queso'].sort_values()
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 418   NaN
# 419   NaN
# 420   NaN
# 421   NaN
# 422   NaN
# Name: Queso, Length: 421, dtype: float64

# %%
df['NonSD'].unique()
# Out:
# array([nan, 'x', 'X'], dtype=object)

# %% [markdown]
# #

# %% [markdown]
# # Clean up the data

# %%
# Get rid of the columns that have high NaN's - greater than 100 in this case
columns = list()
for column in df.columns:
  if df[column].isnull().sum() < 100:
    columns.append(column)
  else:
    pass

columns
# Out:
# ['Burrito',
#  'Date',
#  'Cost',
#  'Hunger',
#  'Tortilla',
#  'Temp',
#  'Meat',
#  'Fillings',
#  'Meat:filling',
#  'Uniformity',
#  'Salsa',
#  'Synergy',
#  'Wrap',
#  'Great']

# %%
df[columns].isnull().sum()
# Out:
# Burrito          0
# Date             0
# Cost             7
# Hunger           3
# Tortilla         0
# Temp            20
# Meat            14
# Fillings         3
# Meat:filling     9
# Uniformity       2
# Salsa           25
# Synergy          2
# Wrap             3
# Great            0
# dtype: int64

# %%
df2 = df[columns].dropna()
df2.head(2)
# Out:
#       Burrito       Date  Cost  Hunger  ...  Salsa  Synergy  Wrap  Great
# 0  California  1/18/2016  6.49     3.0  ...    4.0      4.0   4.0  False
# 1  California  1/24/2016  5.45     3.5  ...    3.5      2.5   5.0  False
#
# [2 rows x 14 columns]

# %%
df2[columns].isnull().sum()
# Out:
# Burrito         0
# Date            0
# Cost            0
# Hunger          0
# Tortilla        0
# Temp            0
# Meat            0
# Fillings        0
# Meat:filling    0
# Uniformity      0
# Salsa           0
# Synergy         0
# Wrap            0
# Great           0
# dtype: int64

# %%
df2[columns].shape
# Out:
# (356, 14)

# %%
# Don't use this - it's just an example
# get rid of '?' and change it to NaN by overwriting the original
# df = df.replace({'?':np.NaN, 'n':0,'y':1})
# df.head()
# https://github.com/jacobpad/DS-Unit-1-Sprint-2-Statistics/blob/master/module1/LS_DS12_121_Statistics_Probability_Assignment.ipynb

# %%
# Get rid of 'NaN's' and replace w/ 0's 
# Get rid of 'x' and replace with 1
# Get rid of 'X' and replace with 1
# by overwriting the original
# df = df.replace({np.NaN:0, 'x':1,'X':1})
# df.head()

# %% [markdown]
# # Fix the date

# %%
# Fix the date thing to the date

# %%
# See what it is
print(df2['Date'].head(1)) # it's an object
# Out:
# 0    1/18/2016
# Name: Date, dtype: object

# %%
# Now make it something usable
# Change the date datatype
print('Before changing --',df2['Date'].dtypes)
df2['Date'] = pd.to_datetime(df2['Date'])
print('Post   changing --',df2['Date'].dtypes)
# Out:
# Before changing -- object
# Post   changing -- datetime64[ns]

# %% [markdown]
# # **Train/Validate/Test Split** - Seperate the Train, Validate & Split - Train on reviews from 2016 & earlier. Validate on 2017. Test on 2018 & later

# %% [markdown]
# ## Fix and set the date

# %%
# Set the Train
start_date = '01-01-1900'
end_date = '12-31-2016'
train = df2[(df2['Date'] > start_date) & (df2['Date'] <= end_date)]
print(train['Date'].min())
print(train['Date'].max())
# Out:
# 2016-01-18 00:00:00
# 2016-12-10 00:00:00

# %%
# Set the Validate
start_date = '01-01-2017'
end_date = '12-31-2017'
validate = df2[(df2['Date'] > start_date) & (df2['Date'] <= end_date)]
print(validate['Date'].min())
print(validate['Date'].max())
# Out:
# 2017-01-07 00:00:00
# 2017-12-29 00:00:00

# %%
# Set the Test
start_date = '01-01-2018'
test = df2[(df2['Date'] > start_date)]
print(test['Date'].min())
print(test['Date'].max())
# Out:
# 2018-01-02 00:00:00
# 2026-04-25 00:00:00

# %%
# Print the shapes
print('Train    -',train.shape)
print('Validate -',validate.shape)
print('Test     -',test.shape)
# Out:
# Train    - (250, 14)
# Validate - (74, 14)
# Test     - (32, 14)

# %% [markdown]
# ## Moving on

# %%
# Do train/validate/test split. Train on reviews from 2016 & earlier. Validate on 2017. Test on 2018 & later.
# Begin with baselines for classification.
# Use scikit-learn for logistic regression.
# Get your model's validation accuracy. (Multiple times if you try multiple iterations.)
# Get your model's test accuracy. (One time, at the end.)
# Commit your notebook to your fork of the GitHub repo.

# %%
train.columns
# Out:
# Index(['Burrito', 'Date', 'Cost', 'Hunger', 'Tortilla', 'Temp', 'Meat',
#        'Fillings', 'Meat:filling', 'Uniformity', 'Salsa', 'Synergy', 'Wrap',
#        'Great'],
#       dtype='object')

# %%
train.describe(include='all').T
# Out:
#              count unique                  top freq  ...     25%   50%  75%    max
# Burrito        250      5           California  106  ...     NaN   NaN  NaN    NaN
# Date           250     98  2016-08-30 00:00:00   25  ...     NaN   NaN  NaN    NaN
# Cost           250    NaN                  NaN  NaN  ...    6.25  6.95  7.5  11.95
# Hunger         250    NaN                  NaN  NaN  ...       3   3.5    4      5
# Tortilla       250    NaN                  NaN  NaN  ...       3   3.5    4      5
# Temp           250    NaN                  NaN  NaN  ...       3     4  4.5      5
# Meat           250    NaN                  NaN  NaN  ...       3   3.5    4      5
# Fillings       250    NaN                  NaN  NaN  ...       3   3.5    4      5
# Meat:filling   250    NaN                  NaN  NaN  ...       3  3.75    4      5
# Uniformity     250    NaN                  NaN  NaN  ...     2.5   3.5    4      5
# Salsa          250    NaN                  NaN  NaN  ...  2.5625   3.5    4      5
# Synergy        250    NaN                  NaN  NaN  ...       3   3.5    4      5
# Wrap           250    NaN                  NaN  NaN  ...     3.5   4.5    5      5
# Great          250      2                False  154  ...     NaN   NaN  NaN    NaN
#
# [14 rows x 13 columns]

# %%
train.describe(exclude='number').T
# Out:
#         count unique                  top freq      first       last
# Burrito   250      5           California  106        NaT        NaT
# Date      250     98  2016-08-30 00:00:00   25 2016-01-18 2016-12-10
# Great     250      2                False  154        NaT        NaT

# %%
train.describe(include='number').columns
# Out:
# Index(['Cost', 'Hunger', 'Tortilla', 'Temp', 'Meat', 'Fillings',
#        'Meat:filling', 'Uniformity', 'Salsa', 'Synergy', 'Wrap'],
#       dtype='object')

# %%
# Set features and target
features = ['Cost', 'Hunger', 'Tortilla', 'Temp', 'Meat', 'Fillings',
       'Meat:filling', 'Uniformity', 'Salsa', 'Synergy', 'Wrap']

target = 'Great'

# %%
# Seperate features and target for the different tests
X_train = train[features]
y_train = train[target]

X_validate = validate[features]
y_validate = validate[target]

X_test = test[features]
y_test = test[target]

# %%
# Encode the catagorical features with one hot encoding
encoder = ce.OneHotEncoder(use_cat_names=True)

# Use the encoder to transform X_train
X_train = encoder.fit_transform(X_train)
print(X_train.shape)
X_train.head(2)
# Out:
# (250, 11)
#    Cost  Hunger  Tortilla  Temp  ...  Uniformity  Salsa  Synergy  Wrap
# 0  6.49     3.0       3.0   5.0  ...         4.0    4.0      4.0   4.0
# 1  5.45     3.5       2.0   3.5  ...         4.0    3.5      2.5   5.0
#
# [2 rows x 11 columns]

# %%
# Checking for NaNs
X_train.isnull().sum()
# Out:
# Cost            0
# Hunger          0
# Tortilla        0
# Temp            0
# Meat            0
# Fillings        0
# Meat:filling    0
# Uniformity      0
# Salsa           0
# Synergy         0
# Wrap            0
# dtype: int64

# %%
# I have no need to impute, but I'll do it for practice...
# Need to impute the missing values before fitting our logistic regression
imputer = SimpleImputer(strategy='mean')

X_train_imputed = imputer.fit_transform(X_train)

# Train data with imputed values
X_train_imputed
# Out:
# array([[6.49, 3.  , 3.  , ..., 4.  , 4.  , 4.  ],
#        [5.45, 3.5 , 2.  , ..., 3.5 , 2.5 , 5.  ],
#        [4.85, 1.5 , 3.  , ..., 3.  , 3.  , 5.  ],
#        ...,
#        [5.49, 3.  , 4.5 , ..., 3.  , 2.5 , 3.  ],
#        [7.75, 4.  , 3.5 , ..., 2.2 , 3.3 , 4.5 ],
#        [7.75, 4.  , 4.  , ..., 2.  , 2.  , 4.  ]])

# %%
# The validation and test data need to be one hot encoded and imputed as well
X_validate = encoder.transform(X_validate)
print(X_validate.head(3),'\n\n\n')

# Using the same training data means (uses transform and not fit_transform)
X_validate_imputed = imputer.transform(X_validate)

# Train data with imputed values
X_validate_imputed
# Out:
#      Cost  Hunger  Tortilla  Temp  ...  Uniformity  Salsa  Synergy  Wrap
# 303  8.50     3.9       3.0   4.5  ...         4.0    4.3      4.2   5.0
# 304  7.90     4.0       3.5   4.0  ...         4.5    4.0      3.8   4.8
# 305  4.99     3.5       2.5   4.5  ...         3.0    2.0      2.0   4.0
#
# [3 rows x 11 columns]
# array([[ 8.5 ,  3.9 ,  3.  ,  4.5 ,  4.1 ,  3.  ,  3.7 ,  4.  ,  4.3 ,
#          4.2 ,  5.  ],
#        [ 7.9 ,  4.  ,  3.5 ,  4.  ,  4.  ,  3.  ,  4.  ,  4.5 ,  4.  ,
#          3.8 ,  4.8 ],
#        [ 7.  ,  4.  ,  4.5 ,  5.  ,  4.  ,  4.  ,  4.  ,  3.7 ,  3.8 ,
#          4.6 ,  4.8 ],
#        [ 6.99,  4.  ,  4.  ,  5.  ,  3.5 ,  3.8 ,  3.  ,  2.5 ,  3.3 ,
#          4.  ,  5.  ],
#        [ 7.1 ,  3.  ,  3.5 ,  5.  ,  4.  ,  4.  ,  4.5 ,  4.75,  3.75,
#          4.  ,  5.  ],
#        [ 6.47,  4.  ,  3.  ,  3.  ,  2.  ,  2.5 ,  1.5 ,  2.5 ,  2.5 ,
#          3.  ,  5.  ],
#        [ 8.94,  3.5 ,  2.5 ,  3.5 ,  3.5 ,  3.5 ,  3.5 ,  4.  ,  3.  ,
#          3.5 ,  4.5 ],
#        [ 5.99,  2.  ,  2.  ,  2.5 ,  4.  ,  3.  ,  4.  ,  3.5 ,  3.  ,
#          3.  ,  5.  ],
#        [ 6.99,  3.5 ,  4.  ,  4.  ,  4.  ,  4.5 ,  4.  ,  3.5 ,  4.  ,
#          4.  ,  4.  ],
#        [ 8.5 ,  3.5 ,  3.5 ,  4.  ,  4.5 ,  4.  ,  3.  ,  4.  ,  3.5 ,
#          4.5 ,  5.  ],
#        [ 8.5 ,  3.5 ,  4.  ,  4.  ,  4.  ,  4.5 ,  4.2 ,  4.5 ,  4.  ,
#          4.5 ,  4.8 ],
#        [ 6.85,  3.5 ,  3.  ,  4.5 ,  3.8 ,  3.8 ,  4.  ,  3.5 ,  3.5 ,
#          4.  ,  3.  ],
#        [ 6.85,  3.5 ,  3.  ,  4.5 ,  4.  ,  4.  ,  4.5 ,  3.  ,  4.  ,
#          4.  ,  3.5 ],
#        [11.5 ,  3.5 ,  2.  ,  2.  ,  4.  ,  3.5 ,  3.  ,  4.5 ,  3.5 ,
#          4.  ,  2.  ],
#        [ 7.89,  4.  ,  4.  ,  3.  ,  4.  ,  4.  ,  3.  ,  4.  ,  3.5 ,
#          4.3 ,  4.5 ],
#        [ 7.89,  5.  ,  5.  ,  5.  ,  5.  ,  5.  ,  4.  ,  4.  ,  5.  ,
#          5.  ,  3.  ]])

# %%
X_test = encoder.transform(X_test)
X_test.head(3)
# Out:
#      Cost  Hunger  Tortilla  Temp  ...  Uniformity  Salsa  Synergy  Wrap
# 77   8.00     4.0       4.5   5.0  ...         5.0    3.0      5.0   5.0
# 386  7.25     4.0       4.0   5.0  ...         3.0    3.0      4.0   5.0
# 387  4.19     3.0       3.0   5.0  ...         1.0    4.0      3.0   4.0
#
# [3 rows x 11 columns]

# %%
# Using the same training data means (uses transform and not fit_transform)
X_test_imputed = imputer.transform(X_test)
# Train data with imputed values
X_test_imputed
# Out:
# array([[8.  , 4.  , 4.5 , 5.  , 5.  , 5.  , 4.5 , 5.  , 3.  , 5.  , 5.  ],
#        [7.25, 4.  , 4.  , 5.  , 4.  , 5.  , 5.  , 3.  , 3.  , 4.  , 5.  ],
#        [6.75, 3.  , 3.  , 4.  , 4.  , 3.  , 4.  , 4.  , 3.  , 3.  , 5.  ],
#        [6.  , 3.  , 4.  , 4.  , 4.5 , 4.  , 3.  , 3.  , 4.5 , 4.  , 4.5 ],
#        [7.9 , 2.  , 4.5 , 3.  , 4.  , 4.5 , 2.5 , 3.5 , 4.  , 5.  , 5.  ],
#        [7.9 , 3.  , 4.  , 4.  , 4.  , 3.7 , 3.  , 2.  , 3.5 , 4.  , 4.5 ],
#        [7.9 , 3.  , 5.  , 2.  , 5.  , 5.  , 5.  , 2.  , 5.  , 5.  , 2.  ],
#        [5.5 , 3.5 , 3.  , 5.  , 4.3 , 4.  , 4.9 , 3.8 , 3.  , 4.5 , 4.  ]])

# %%
print('Train shape:      ', len(X_train_imputed), len(X_train_imputed[0]))
print('Validation shape: ', len(X_validate_imputed),'', len(X_validate_imputed[0]))
print('Test shape:       ', len(X_test_imputed),'', len(X_test_imputed[0]))
# Out:
# Train shape:       250 11
# Validation shape:  74  11
# Test shape:        32  11

# %% [markdown]
# # Baseline

# %%
# Target = 'Great'
# Baseline accuracy - percentage correct if just guessing the most 
#   common 'Great' classification (True of False)
baseline = train['Great'].value_counts(normalize=True).max()
print("Train Accuracy:", baseline*100,'%')
# Out:
# Train Accuracy: 61.6 %

# %% [markdown]
# # Standardizing before fitting the logistic regression model

# %%
# Standardizing before fitting
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_imputed)
X_validate_scaled = scaler.transform(X_validate_imputed)
X_test_scaled = scaler.transform(X_validate_imputed)

# %% [markdown]
# # Logestic Regression

# %%
# Creating logistic regression model
model = LogisticRegressionCV()

# Fitting model onto data
model.fit(X_train_scaled, y_train)

# Getting predicted targets of the validation set
y_pred = model.predict(X_validate_scaled)

# Checking the accuracy of the validation set
log_reg_validate = accuracy_score(y_validate, y_pred)
print("Validation Accuracy:", log_reg_validate)
# Out:
# Validation Accuracy: 0.8648648648648649

# %%
# See the shape
print('Train shape:', len(X_train_scaled), len(X_train_scaled[0]))
print('Validation shape:', len(X_validate_scaled), len(X_validate_scaled[0]))
# Out:
# Train shape: 250 11
# Validation shape: 74 11

# %%
# Recombine training and validation features
X_complete_train = np.concatenate([X_train_imputed, X_validate_imputed])

# Recombine training and validation targets
y_complete_train = pd.concat([y_train, y_validate], axis=0)

# %% [markdown]
# # Check accuracy on testing data

# %%
# Creating model
model = LogisticRegressionCV()

# Fitting model onto data
model.fit(X_complete_train, y_complete_train)

# Getting predicted targets
y_test_pred = model.predict(X_test_imputed)

# Checking the accuracy of the validation set
log_reg_test = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", log_reg_test)
# Out:
# Test Accuracy: 0.8125

# %% [markdown]
# # Results

# %%
print("Baseline Train Accuracy:", baseline)
print("Validation Accuracy:", log_reg_validate)
print("Test Accuracy:", log_reg_test)
# Out:
# Baseline Train Accuracy: 0.616
# Validation Accuracy: 0.8648648648648649
# Test Accuracy: 0.8125

# %%
# Test was not as good as the validate
