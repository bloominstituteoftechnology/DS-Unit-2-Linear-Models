# %% [markdown]
# <a href="https://colab.research.google.com/github/fuse999/DS-Unit-2-Regression-Classification/blob/master/module4/Riley_assignment_applied_modeling_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 4*
#
# ---
#
#
# # Model Interpretation 2
#
# You will use your portfolio project dataset for all assignments this sprint.
#
# ## Assignment
#
# Complete these tasks for your project, and document your work.
#
# - [ ] Continue to iterate on your project: data cleaning, exploratory visualization, feature engineering, modeling.
# - [ ] Make a Shapley force plot to explain at least 1 individual prediction.
# - [ ] Share at least 1 visualization (of any type) on Slack.
#
# But, if you aren't ready to make a Shapley force plot with your own dataset today, that's okay. You can practice this objective with another dataset instead. You may choose any dataset you've worked with previously.
#
# ## Stretch Goals
# - [ ] Make Shapley force plots to explain at least 4 individual predictions.
#     - If your project is Binary Classification, you can do a True Positive, True Negative, False Positive, False Negative.
#     - If your project is Regression, you can do a high prediction with low error, a low prediction with low error, a high prediction with high error, and a low prediction with high error.
# - [ ] Use Shapley values to display verbal explanations of individual predictions.
# - [ ] Use the SHAP library for other visualization types.
#
# The [SHAP repo](https://github.com/slundberg/shap) has examples for many visualization types, including:
#
# - Force Plot, individual predictions
# - Force Plot, multiple predictions
# - Dependence Plot
# - Summary Plot
# - Summary Plot, Bar
# - Interaction Values
# - Decision Plots
#
# We just did the first type during the lesson. The [Kaggle microcourse](https://www.kaggle.com/dansbecker/advanced-uses-of-shap-values) shows two more. Experiment and see what you can learn!
#
#
# ## Links
# - [Kaggle / Dan Becker: Machine Learning Explainability — SHAP Values](https://www.kaggle.com/learn/machine-learning-explainability)
# - [Christoph Molnar: Interpretable Machine Learning — Shapley Values](https://christophm.github.io/interpretable-ml-book/shapley.html)
# - [SHAP repo](https://github.com/slundberg/shap) & [docs](https://shap.readthedocs.io/en/latest/)

# %%
import pandas as pd
df = pd.read_csv('gradcafe.csv')

# %%
# Removeing others values
df = df[df.decision != 'Others']
df = df.replace({'Accepted':1, 'Rejected':0})

# %%
df = df.dropna()

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df,test_size=0.2,
                               stratify=df['decision'],
                               random_state=59)

train, val = train_test_split(train, test_size=0.25,
                              stratify=train['decision'],
                              random_state=59)
train.shape, val.shape, test.shape
# Out:
# ((426415, 14), (142139, 14), (142139, 14))

# %%
# Baseline

from sklearn.metrics import accuracy_score
y_pred = [1] * len(df['decision'])
accuracy_score(df['decision'], y_pred)
# Out:
# 0.5612310800866197

# %%
df.columns
# Out:
# Index(['comment', 'major', 'gre_quant', 'degree', 'season', 'decision',
#        'gre_verbal', 'date_of_result', 'term_year', 'undergrad_gpa',
#        'date_added', 'applicant_status', 'university', 'gre_awa'],
#       dtype='object')

# %%
def wrangle(X):
# Wrangle train, validate, and test sets
    
    # Prevent SettingWithCopyWarning (in acordince with lectuere)
    X = X.copy()
  
    #X = X.drop(columns=['gre_awa'])
      # return the wrangled dataframe
    return X

train = wrangle(train)
val = wrangle(val)
test = wrangle(test)

# creating target and features lsts
target = 'decision'
train_features = train.drop(columns=[target])
numeric_features = train_features.select_dtypes(include='number').columns.tolist()
cardinality = train_features.select_dtypes(exclude='number').nunique()
categorical_features = cardinality[cardinality <= 50].index.tolist()
features = numeric_features + categorical_features
print(features)
# Out:
# ['gre_quant', 'gre_verbal', 'term_year', 'undergrad_gpa', 'gre_awa', 'degree', 'season', 'applicant_status']

# %%
# creating Train, Validation, and Test vars
X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]
y_test = test[target]
from sklearn.pipeline import make_pipeline
import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='most_frequent'), 
    RandomForestClassifier(n_estimators=350, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
#pipeline.fit(X_train, y_train)
pipeline.fit(X_train, y_train)
print('Validation Accuracy', pipeline.score(X_val, y_val))
# Out:
# Validation Accuracy 0.904804451980104

# %%
# This ROC score worrys me 
scores = cross_val_score(pipeline, X_train, y_train, cv=3, scoring='roc_auc')
print('Validation ROC AUC:', scores)
# Out:
# Validation ROC AUC: [0.98006542 0.98041277 0.98014717]

# %%
from sklearn.metrics import r2_score
from xgboost import XGBRegressor

from sklearn.pipeline import make_pipeline
import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score
gb = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='most_frequent'), 
    XGBRegressor(n_estimators=200, objective='reg:squarederror', n_jobs=-1)
)

gb.fit(X_train, y_train)
y_pred = gb.predict(X_val)
print('Gradient Boosting R^2', r2_score(y_val, y_pred))
# Out:
# C:\Users\riley\Anaconda3\envs\unit2\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\riley\Anaconda3\envs\unit2\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# Gradient Boosting R^2 0.12028099141357096

# %%
# Get the permutation importance
transformers = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median')
)

X_train_transformed = transformers.fit_transform(X_train)
X_val_transformed = transformers.transform(X_val)

model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
model.fit(X_train_transformed, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
import eli5
from eli5.sklearn import PermutationImportance

permuter = PermutationImportance(
    model, 
    scoring='accuracy', 
    n_iter=5, 
    random_state=42
)

permuter.fit(X_val_transformed, y_val)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=RandomForestClassifier(bootstrap=True,
#                                                        class_weight=None,
#                                                        criterion='gini',
#                                                        max_depth=None,
#                                                        max_features='auto',
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        n_estimators=100,
#                                                        n_jobs=-1,
#                                                        oob_score=False,
#                                                        random_state=42,
#                                                        verbose=0,
#                                                        warm_start=False),
#                       n_iter=5, random_state=42, refit=True,
#                       scoring='accuracy')

# %%
feature_names = X_val.columns.tolist()
pd.Series(permuter.feature_importances_, feature_names).sort_values(ascending=False)
# Out:
# undergrad_gpa       0.197144
# gre_verbal          0.189436
# term_year           0.148201
# gre_quant           0.136911
# applicant_status    0.122949
# degree              0.108177
# gre_awa             0.100925
# season              0.005858
# dtype: float64

# %%
eli5.show_weights(
    permuter, 
    top=None, # show permutation importances for all features
    feature_names=feature_names
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1971
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 undergrad_gpa
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1894
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gre_verbal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1482
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 term_year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1369
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gre_quant
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1229
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 applicant_status
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1082
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 degree
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1009
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gre_awa
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0059
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 season
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
# Use Pdpbox
# %matplotlib inline
import matplotlib.pyplot as plt
from pdpbox import pdp
feature = 'gre_awa'
pdp_dist = pdp.pdp_isolate(model=pipeline,
                           dataset=X_train,
                           model_features=features,
                           feature=feature)
pdp.pdp_plot(pdp_dist, feature);

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier

processor = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median')
)

X_train_processed = processor.fit_transform(X_train)
X_val_processed = processor.transform(X_val)

eval_set = [(X_train_processed, y_train), 
            (X_val_processed, y_val)]

model = XGBClassifier(n_estimators=1000, n_jobs=-1)
model.fit(X_train_processed, y_train, eval_set=eval_set, eval_metric='auc', 
          early_stopping_rounds=10)
# Out:
# [0]	validation_0-auc:0.580441	validation_1-auc:0.581266
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.582726	validation_1-auc:0.58354
# [2]	validation_0-auc:0.589647	validation_1-auc:0.590821
# [3]	validation_0-auc:0.594323	validation_1-auc:0.595433
# [4]	validation_0-auc:0.594926	validation_1-auc:0.596199
# [5]	validation_0-auc:0.59458	validation_1-auc:0.596066
# [6]	validation_0-auc:0.595684	validation_1-auc:0.596965
# [7]	validation_0-auc:0.596424	validation_1-auc:0.597656
# [8]	validation_0-auc:0.5975	validation_1-auc:0.598862
# [9]	validation_0-auc:0.602738	validation_1-auc:0.603841
# [10]	validation_0-auc:0.607071	validation_1-auc:0.608461
# [11]	validation_0-auc:0.607806	validation_1-auc:0.609301
# [12]	validation_0-auc:0.609146	validation_1-auc:0.610868
# [13]	validation_0-auc:0.609635	validation_1-auc:0.611283
# [14]	validation_0-auc:0.612494	validation_1-auc:0.613921
# [15]	validation_0-auc:0.612842	validation_1-auc:0.614269
# [16]	validation_0-auc:0.614089	validation_1-auc:0.61556
# [17]	validation_0-auc:0.616683	validation_1-auc:0.617909
# [18]	validation_0-auc:0.620146	validation_1-auc:0.62136
# [19]	validation_0-auc:0.621548	validation_1-auc:0.622891
# [20]	validation_0-auc:0.623023	validation_1-auc:0.624701
# [21]	validation_0-auc:0.623254	validation_1-auc:0.62504
# [22]	validation_0-auc:0.624287	validation_1-auc:0.626167
# [23]	validation_0-auc:0.625679	validation_1-auc:0.627741
# [24]	validation_0-auc:0.626353	validation_1-auc:0.628288
# [25]	validation_0-auc:0.627587	validation_1-auc:0.629605
# [26]	validation_0-auc:0.63026	validation_1-auc:0.632358
# [27]	validation_0-auc:0.631301	validation_1-auc:0.633359
# [28]	validation_0-auc:0.632488	validation_1-auc:0.634534
# [29]	validation_0-auc:0.633062	validation_1-auc:0.635258
# [30]	validation_0-auc:0.633914	validation_1-auc:0.636168
# [31]	validation_0-auc:0.635303	validation_1-auc:0.63731
# [32]	validation_0-auc:0.636614	validation_1-auc:0.63849
# [33]	validation_0-auc:0.637064	validation_1-auc:0.638973
# [34]	validation_0-auc:0.63813	validation_1-auc:0.640099
# [35]	validation_0-auc:0.639722	validation_1-auc:0.641626
# [36]	validation_0-auc:0.639589	validation_1-auc:0.641595
# [37]	validation_0-auc:0.640426	validation_1-auc:0.642417
# [38]	validation_0-auc:0.641089	validation_1-auc:0.643199
# [39]	validation_0-auc:0.642145	validation_1-auc:0.644105
# [40]	validation_0-auc:0.643749	validation_1-auc:0.645552
# [41]	validation_0-auc:0.645183	validation_1-auc:0.646975
# [42]	validation_0-auc:0.646552	validation_1-auc:0.648123
# [43]	validation_0-auc:0.647429	validation_1-auc:0.648945
# [44]	validation_0-auc:0.64773	validation_1-auc:0.649276
# [45]	validation_0-auc:0.648207	validation_1-auc:0.649732
# [46]	validation_0-auc:0.64924	validation_1-auc:0.650654
# [47]	validation_0-auc:0.650128	validation_1-auc:0.65147
# [48]	validation_0-auc:0.65033	validation_1-auc:0.651662
# [49]	validation_0-auc:0.651824	validation_1-auc:0.653214
# [50]	validation_0-auc:0.652223	validation_1-auc:0.653689
# [51]	validation_0-auc:0.653472	validation_1-auc:0.654756
# [52]	validation_0-auc:0.653565	validation_1-auc:0.65481
# [53]	validation_0-auc:0.654396	validation_1-auc:0.655491
# [54]	validation_0-auc:0.654862	validation_1-auc:0.656101
# [55]	validation_0-auc:0.655514	validation_1-auc:0.656705
# [56]	validation_0-auc:0.656554	validation_1-auc:0.657682
# [57]	validation_0-auc:0.657659	validation_1-auc:0.65874
# [58]	validation_0-auc:0.657744	validation_1-auc:0.658798
# [59]	validation_0-auc:0.658308	validation_1-auc:0.659313
# [60]	validation_0-auc:0.658762	validation_1-auc:0.659736
# [61]	validation_0-auc:0.659597	validation_1-auc:0.660718
# [62]	validation_0-auc:0.660231	validation_1-auc:0.661348
# [63]	validation_0-auc:0.660879	validation_1-auc:0.661932
# [64]	validation_0-auc:0.661407	validation_1-auc:0.662501
# [65]	validation_0-auc:0.661643	validation_1-auc:0.662734
# [66]	validation_0-auc:0.66205	validation_1-auc:0.663111
# [67]	validation_0-auc:0.662641	validation_1-auc:0.663624
# [68]	validation_0-auc:0.662786	validation_1-auc:0.663762
# [69]	validation_0-auc:0.663769	validation_1-auc:0.664662
# [70]	validation_0-auc:0.664279	validation_1-auc:0.665099
# [71]	validation_0-auc:0.664718	validation_1-auc:0.665546
# [72]	validation_0-auc:0.665524	validation_1-auc:0.666422
# [73]	validation_0-auc:0.666656	validation_1-auc:0.667624
# [74]	validation_0-auc:0.666859	validation_1-auc:0.667789
# [75]	validation_0-auc:0.667661	validation_1-auc:0.668472
# [76]	validation_0-auc:0.668414	validation_1-auc:0.669215
# [77]	validation_0-auc:0.66871	validation_1-auc:0.669534
# [78]	validation_0-auc:0.669112	validation_1-auc:0.670018
# [79]	validation_0-auc:0.669226	validation_1-auc:0.670135
# [80]	validation_0-auc:0.669426	validation_1-auc:0.670374
# [81]	validation_0-auc:0.670494	validation_1-auc:0.671538
# [82]	validation_0-auc:0.671161	validation_1-auc:0.672206
# [83]	validation_0-auc:0.671459	validation_1-auc:0.672439
# [84]	validation_0-auc:0.672057	validation_1-auc:0.67315
# [85]	validation_0-auc:0.672484	validation_1-auc:0.673538
# [86]	validation_0-auc:0.67283	validation_1-auc:0.673858
# [87]	validation_0-auc:0.672889	validation_1-auc:0.673914
# [88]	validation_0-auc:0.673854	validation_1-auc:0.674882
# [89]	validation_0-auc:0.674785	validation_1-auc:0.675841
# [90]	validation_0-auc:0.675386	validation_1-auc:0.676498
# [91]	validation_0-auc:0.675597	validation_1-auc:0.676723
# [92]	validation_0-auc:0.676405	validation_1-auc:0.677427
# [93]	validation_0-auc:0.676884	validation_1-auc:0.677897
# [94]	validation_0-auc:0.677666	validation_1-auc:0.678724
# [95]	validation_0-auc:0.677706	validation_1-auc:0.67875
# [96]	validation_0-auc:0.678128	validation_1-auc:0.679137
# [97]	validation_0-auc:0.678279	validation_1-auc:0.679283
# [98]	validation_0-auc:0.678908	validation_1-auc:0.679932
# [99]	validation_0-auc:0.679456	validation_1-auc:0.680485
# [100]	validation_0-auc:0.679718	validation_1-auc:0.680748
# [101]	validation_0-auc:0.68013	validation_1-auc:0.68121
# [102]	validation_0-auc:0.680488	validation_1-auc:0.681523
# [103]	validation_0-auc:0.680772	validation_1-auc:0.681731
# [104]	validation_0-auc:0.680848	validation_1-auc:0.681746
# [105]	validation_0-auc:0.680901	validation_1-auc:0.68178
# [106]	validation_0-auc:0.68198	validation_1-auc:0.682734
# [107]	validation_0-auc:0.682634	validation_1-auc:0.683409
# [108]	validation_0-auc:0.683336	validation_1-auc:0.68417
# [109]	validation_0-auc:0.683451	validation_1-auc:0.684281
# [110]	validation_0-auc:0.683662	validation_1-auc:0.684491
# [111]	validation_0-auc:0.684291	validation_1-auc:0.685019
# [112]	validation_0-auc:0.68471	validation_1-auc:0.685362
# [113]	validation_0-auc:0.685177	validation_1-auc:0.685881
# [114]	validation_0-auc:0.685507	validation_1-auc:0.686185
# [115]	validation_0-auc:0.68559	validation_1-auc:0.686248
# [116]	validation_0-auc:0.686344	validation_1-auc:0.687043
# [117]	validation_0-auc:0.686639	validation_1-auc:0.687337
# [118]	validation_0-auc:0.686758	validation_1-auc:0.687449
# [119]	validation_0-auc:0.686768	validation_1-auc:0.687459
# [120]	validation_0-auc:0.68805	validation_1-auc:0.688838
# [121]	validation_0-auc:0.688507	validation_1-auc:0.689215
# [122]	validation_0-auc:0.688641	validation_1-auc:0.689316
# [123]	validation_0-auc:0.688885	validation_1-auc:0.6896
# [124]	validation_0-auc:0.68897	validation_1-auc:0.689695
# [125]	validation_0-auc:0.689261	validation_1-auc:0.689969
# [126]	validation_0-auc:0.690189	validation_1-auc:0.690926
# [127]	validation_0-auc:0.690903	validation_1-auc:0.691633
# [128]	validation_0-auc:0.691007	validation_1-auc:0.691755
# [129]	validation_0-auc:0.691224	validation_1-auc:0.691935
# [130]	validation_0-auc:0.691281	validation_1-auc:0.691986
# [131]	validation_0-auc:0.692019	validation_1-auc:0.692755
# [132]	validation_0-auc:0.692532	validation_1-auc:0.693285
# [133]	validation_0-auc:0.693416	validation_1-auc:0.694106
# [134]	validation_0-auc:0.693579	validation_1-auc:0.694271
# [135]	validation_0-auc:0.694195	validation_1-auc:0.694883
# [136]	validation_0-auc:0.69519	validation_1-auc:0.69593
# [137]	validation_0-auc:0.696005	validation_1-auc:0.696709
# [138]	validation_0-auc:0.696155	validation_1-auc:0.696896
# [139]	validation_0-auc:0.696607	validation_1-auc:0.697296
# [140]	validation_0-auc:0.69667	validation_1-auc:0.697393
# [141]	validation_0-auc:0.697292	validation_1-auc:0.69801
# [142]	validation_0-auc:0.697902	validation_1-auc:0.698525
# [143]	validation_0-auc:0.698357	validation_1-auc:0.698907
# [144]	validation_0-auc:0.698365	validation_1-auc:0.698915
# [145]	validation_0-auc:0.698851	validation_1-auc:0.699381
# [146]	validation_0-auc:0.698996	validation_1-auc:0.699581
# [147]	validation_0-auc:0.699417	validation_1-auc:0.699973
# [148]	validation_0-auc:0.699539	validation_1-auc:0.700078
# [149]	validation_0-auc:0.699571	validation_1-auc:0.700103
# [150]	validation_0-auc:0.699525	validation_1-auc:0.70008
# [151]	validation_0-auc:0.699878	validation_1-auc:0.700413
# [152]	validation_0-auc:0.700011	validation_1-auc:0.700534
# [153]	validation_0-auc:0.700045	validation_1-auc:0.700521
# [154]	validation_0-auc:0.700122	validation_1-auc:0.70059
# [155]	validation_0-auc:0.700238	validation_1-auc:0.70069
# [156]	validation_0-auc:0.700312	validation_1-auc:0.700753
# [157]	validation_0-auc:0.700498	validation_1-auc:0.700991
# [158]	validation_0-auc:0.701366	validation_1-auc:0.701738
# [159]	validation_0-auc:0.701371	validation_1-auc:0.701744
# [160]	validation_0-auc:0.701577	validation_1-auc:0.701937
# [161]	validation_0-auc:0.702012	validation_1-auc:0.702411
# [162]	validation_0-auc:0.702552	validation_1-auc:0.702939
# [163]	validation_0-auc:0.703125	validation_1-auc:0.703397
# [164]	validation_0-auc:0.703471	validation_1-auc:0.70378
# [165]	validation_0-auc:0.703823	validation_1-auc:0.704101
# [166]	validation_0-auc:0.704401	validation_1-auc:0.704751
# [167]	validation_0-auc:0.704814	validation_1-auc:0.705169
# [168]	validation_0-auc:0.704918	validation_1-auc:0.705273
# [169]	validation_0-auc:0.705305	validation_1-auc:0.705652
# [170]	validation_0-auc:0.705564	validation_1-auc:0.705932
# [171]	validation_0-auc:0.705647	validation_1-auc:0.70601
# [172]	validation_0-auc:0.705751	validation_1-auc:0.706112
# [173]	validation_0-auc:0.706407	validation_1-auc:0.70678
# [174]	validation_0-auc:0.706824	validation_1-auc:0.707221
# [175]	validation_0-auc:0.707117	validation_1-auc:0.707531
# [176]	validation_0-auc:0.70712	validation_1-auc:0.707534
# [177]	validation_0-auc:0.707139	validation_1-auc:0.707532
# [178]	validation_0-auc:0.707136	validation_1-auc:0.707524
# [179]	validation_0-auc:0.707468	validation_1-auc:0.707864
# [180]	validation_0-auc:0.707729	validation_1-auc:0.708122
# [181]	validation_0-auc:0.707632	validation_1-auc:0.707996
# [182]	validation_0-auc:0.708021	validation_1-auc:0.708394
# [183]	validation_0-auc:0.708111	validation_1-auc:0.708467
# [184]	validation_0-auc:0.708432	validation_1-auc:0.708804
# [185]	validation_0-auc:0.708764	validation_1-auc:0.709141
# [186]	validation_0-auc:0.709377	validation_1-auc:0.709802
# [187]	validation_0-auc:0.709566	validation_1-auc:0.710037
# [188]	validation_0-auc:0.710084	validation_1-auc:0.710633
# [189]	validation_0-auc:0.710125	validation_1-auc:0.710679
# [190]	validation_0-auc:0.71017	validation_1-auc:0.710731
# [191]	validation_0-auc:0.710544	validation_1-auc:0.711081
# [192]	validation_0-auc:0.710909	validation_1-auc:0.711442
# [193]	validation_0-auc:0.710916	validation_1-auc:0.711446
# [194]	validation_0-auc:0.711044	validation_1-auc:0.711579
# [195]	validation_0-auc:0.711358	validation_1-auc:0.711856
# [196]	validation_0-auc:0.711606	validation_1-auc:0.712084
# [197]	validation_0-auc:0.711823	validation_1-auc:0.712271
# [198]	validation_0-auc:0.712167	validation_1-auc:0.712649
# [199]	validation_0-auc:0.712211	validation_1-auc:0.712672
# [200]	validation_0-auc:0.712494	validation_1-auc:0.713022
# [201]	validation_0-auc:0.71328	validation_1-auc:0.71381
# [202]	validation_0-auc:0.713438	validation_1-auc:0.713951
# [203]	validation_0-auc:0.713442	validation_1-auc:0.713955
# [204]	validation_0-auc:0.713511	validation_1-auc:0.714035
# [205]	validation_0-auc:0.714819	validation_1-auc:0.715294
# [206]	validation_0-auc:0.714776	validation_1-auc:0.715242
# [207]	validation_0-auc:0.715173	validation_1-auc:0.715618
# [208]	validation_0-auc:0.715464	validation_1-auc:0.715845
# [209]	validation_0-auc:0.715864	validation_1-auc:0.716257
# [210]	validation_0-auc:0.715889	validation_1-auc:0.716306
# [211]	validation_0-auc:0.716121	validation_1-auc:0.716479
# [212]	validation_0-auc:0.716401	validation_1-auc:0.716725
# [213]	validation_0-auc:0.716519	validation_1-auc:0.716851
# [214]	validation_0-auc:0.716967	validation_1-auc:0.717312
# [215]	validation_0-auc:0.717303	validation_1-auc:0.717657
# [216]	validation_0-auc:0.717306	validation_1-auc:0.71766
# [217]	validation_0-auc:0.71766	validation_1-auc:0.718023
# [218]	validation_0-auc:0.717667	validation_1-auc:0.718027
# [219]	validation_0-auc:0.717903	validation_1-auc:0.718219
# [220]	validation_0-auc:0.718085	validation_1-auc:0.718434
# [221]	validation_0-auc:0.718346	validation_1-auc:0.718655
# [222]	validation_0-auc:0.718437	validation_1-auc:0.718752
# [223]	validation_0-auc:0.718594	validation_1-auc:0.718887
# [224]	validation_0-auc:0.718939	validation_1-auc:0.719175
# [225]	validation_0-auc:0.719196	validation_1-auc:0.719454
# [226]	validation_0-auc:0.719533	validation_1-auc:0.719825
# [227]	validation_0-auc:0.719653	validation_1-auc:0.719946
# [228]	validation_0-auc:0.719886	validation_1-auc:0.720156
# [229]	validation_0-auc:0.720141	validation_1-auc:0.720399
# [230]	validation_0-auc:0.720785	validation_1-auc:0.721016
# [231]	validation_0-auc:0.72131	validation_1-auc:0.721539
# [232]	validation_0-auc:0.72152	validation_1-auc:0.721754
# [233]	validation_0-auc:0.721687	validation_1-auc:0.721909
# [234]	validation_0-auc:0.72196	validation_1-auc:0.722197
# [235]	validation_0-auc:0.721903	validation_1-auc:0.722142
# [236]	validation_0-auc:0.722217	validation_1-auc:0.722441
# [237]	validation_0-auc:0.722556	validation_1-auc:0.722758
# [238]	validation_0-auc:0.723017	validation_1-auc:0.72322
# [239]	validation_0-auc:0.723734	validation_1-auc:0.723943
# [240]	validation_0-auc:0.724079	validation_1-auc:0.724302
# [241]	validation_0-auc:0.724229	validation_1-auc:0.724434
# [242]	validation_0-auc:0.724319	validation_1-auc:0.724522
# [243]	validation_0-auc:0.724429	validation_1-auc:0.724624
# [244]	validation_0-auc:0.724695	validation_1-auc:0.724835
# [245]	validation_0-auc:0.724892	validation_1-auc:0.725035
# [246]	validation_0-auc:0.724981	validation_1-auc:0.725112
# [247]	validation_0-auc:0.725186	validation_1-auc:0.725324
# [248]	validation_0-auc:0.725209	validation_1-auc:0.725342
# [249]	validation_0-auc:0.725263	validation_1-auc:0.725386
# [250]	validation_0-auc:0.72547	validation_1-auc:0.725535
# [251]	validation_0-auc:0.725861	validation_1-auc:0.725922
# [252]	validation_0-auc:0.726432	validation_1-auc:0.726477
# [253]	validation_0-auc:0.726567	validation_1-auc:0.726629
# [254]	validation_0-auc:0.726726	validation_1-auc:0.726829
# [255]	validation_0-auc:0.727247	validation_1-auc:0.727313
# [256]	validation_0-auc:0.727373	validation_1-auc:0.727462
# [257]	validation_0-auc:0.72739	validation_1-auc:0.727505
# [258]	validation_0-auc:0.727858	validation_1-auc:0.727977
# [259]	validation_0-auc:0.72801	validation_1-auc:0.728106
# [260]	validation_0-auc:0.728008	validation_1-auc:0.728107
# [261]	validation_0-auc:0.72813	validation_1-auc:0.728182
# [262]	validation_0-auc:0.728235	validation_1-auc:0.728302
# [263]	validation_0-auc:0.72844	validation_1-auc:0.728487
# [264]	validation_0-auc:0.728597	validation_1-auc:0.728596
# [265]	validation_0-auc:0.728664	validation_1-auc:0.728678
# [266]	validation_0-auc:0.728672	validation_1-auc:0.728683
# [267]	validation_0-auc:0.728719	validation_1-auc:0.72875
# [268]	validation_0-auc:0.728896	validation_1-auc:0.728915
# [269]	validation_0-auc:0.728931	validation_1-auc:0.728944
# [270]	validation_0-auc:0.729018	validation_1-auc:0.729033
# [271]	validation_0-auc:0.729134	validation_1-auc:0.729114
# [272]	validation_0-auc:0.729311	validation_1-auc:0.7293
# [273]	validation_0-auc:0.729666	validation_1-auc:0.729604
# [274]	validation_0-auc:0.730229	validation_1-auc:0.73016
# [275]	validation_0-auc:0.73031	validation_1-auc:0.730223
# [276]	validation_0-auc:0.730642	validation_1-auc:0.730577
# [277]	validation_0-auc:0.730719	validation_1-auc:0.730635
# [278]	validation_0-auc:0.730807	validation_1-auc:0.730708
# [279]	validation_0-auc:0.730903	validation_1-auc:0.730764
# [280]	validation_0-auc:0.731419	validation_1-auc:0.731323
# [281]	validation_0-auc:0.731467	validation_1-auc:0.731404
# [282]	validation_0-auc:0.731527	validation_1-auc:0.731454
# [283]	validation_0-auc:0.731538	validation_1-auc:0.73146
# [284]	validation_0-auc:0.731557	validation_1-auc:0.731465
# [285]	validation_0-auc:0.731606	validation_1-auc:0.731507
# [286]	validation_0-auc:0.731781	validation_1-auc:0.731688
# [287]	validation_0-auc:0.731845	validation_1-auc:0.731773
# [288]	validation_0-auc:0.732154	validation_1-auc:0.732029
# [289]	validation_0-auc:0.732221	validation_1-auc:0.732072
# [290]	validation_0-auc:0.732743	validation_1-auc:0.732643
# [291]	validation_0-auc:0.733024	validation_1-auc:0.732913
# [292]	validation_0-auc:0.733129	validation_1-auc:0.733014
# [293]	validation_0-auc:0.733393	validation_1-auc:0.7333
# [294]	validation_0-auc:0.73344	validation_1-auc:0.733335
# [295]	validation_0-auc:0.733645	validation_1-auc:0.733492
# [296]	validation_0-auc:0.733671	validation_1-auc:0.733561
# [297]	validation_0-auc:0.733982	validation_1-auc:0.733849
# [298]	validation_0-auc:0.734065	validation_1-auc:0.733931
# [299]	validation_0-auc:0.734118	validation_1-auc:0.733975
# [300]	validation_0-auc:0.734392	validation_1-auc:0.734219
# [301]	validation_0-auc:0.734446	validation_1-auc:0.734261
# [302]	validation_0-auc:0.73481	validation_1-auc:0.734569
# [303]	validation_0-auc:0.735425	validation_1-auc:0.735181
# [304]	validation_0-auc:0.736203	validation_1-auc:0.735975
# [305]	validation_0-auc:0.736396	validation_1-auc:0.736142
# [306]	validation_0-auc:0.736627	validation_1-auc:0.736399
# [307]	validation_0-auc:0.736735	validation_1-auc:0.736517
# [308]	validation_0-auc:0.736889	validation_1-auc:0.736683
# [309]	validation_0-auc:0.736915	validation_1-auc:0.736691
# [310]	validation_0-auc:0.736964	validation_1-auc:0.736741
# [311]	validation_0-auc:0.737117	validation_1-auc:0.736897
# [312]	validation_0-auc:0.737685	validation_1-auc:0.737413
# [313]	validation_0-auc:0.737986	validation_1-auc:0.73768
# [314]	validation_0-auc:0.738573	validation_1-auc:0.738308
# [315]	validation_0-auc:0.738609	validation_1-auc:0.738333
# [316]	validation_0-auc:0.738812	validation_1-auc:0.73849
# [317]	validation_0-auc:0.739081	validation_1-auc:0.738773
# [318]	validation_0-auc:0.739197	validation_1-auc:0.738877
# [319]	validation_0-auc:0.739192	validation_1-auc:0.738875
# [320]	validation_0-auc:0.739436	validation_1-auc:0.73913
# [321]	validation_0-auc:0.739686	validation_1-auc:0.739374
# [322]	validation_0-auc:0.739899	validation_1-auc:0.739601
# [323]	validation_0-auc:0.740161	validation_1-auc:0.739837
# [324]	validation_0-auc:0.74037	validation_1-auc:0.740038
# [325]	validation_0-auc:0.740506	validation_1-auc:0.740194
# [326]	validation_0-auc:0.740596	validation_1-auc:0.740304
# [327]	validation_0-auc:0.740781	validation_1-auc:0.740493
# [328]	validation_0-auc:0.740837	validation_1-auc:0.74056
# [329]	validation_0-auc:0.740872	validation_1-auc:0.740618
# [330]	validation_0-auc:0.740856	validation_1-auc:0.740574
# [331]	validation_0-auc:0.741384	validation_1-auc:0.741111
# [332]	validation_0-auc:0.741671	validation_1-auc:0.741356
# [333]	validation_0-auc:0.741844	validation_1-auc:0.741515
# [334]	validation_0-auc:0.741949	validation_1-auc:0.741656
# [335]	validation_0-auc:0.742163	validation_1-auc:0.741865
# [336]	validation_0-auc:0.742375	validation_1-auc:0.742083
# [337]	validation_0-auc:0.74263	validation_1-auc:0.742329
# [338]	validation_0-auc:0.742777	validation_1-auc:0.742457
# [339]	validation_0-auc:0.743221	validation_1-auc:0.742922
# [340]	validation_0-auc:0.74328	validation_1-auc:0.742973
# [341]	validation_0-auc:0.74329	validation_1-auc:0.742984
# [342]	validation_0-auc:0.743354	validation_1-auc:0.743052
# [343]	validation_0-auc:0.743383	validation_1-auc:0.743106
# [344]	validation_0-auc:0.743539	validation_1-auc:0.743245
# [345]	validation_0-auc:0.743586	validation_1-auc:0.743274
# [346]	validation_0-auc:0.743663	validation_1-auc:0.74334
# [347]	validation_0-auc:0.743788	validation_1-auc:0.743456
# [348]	validation_0-auc:0.743949	validation_1-auc:0.743601
# [349]	validation_0-auc:0.744051	validation_1-auc:0.74371
# [350]	validation_0-auc:0.744307	validation_1-auc:0.743955
# [351]	validation_0-auc:0.744516	validation_1-auc:0.744166
# [352]	validation_0-auc:0.744649	validation_1-auc:0.744265
# [353]	validation_0-auc:0.744821	validation_1-auc:0.744442
# [354]	validation_0-auc:0.744925	validation_1-auc:0.744507
# [355]	validation_0-auc:0.744922	validation_1-auc:0.744512
# [356]	validation_0-auc:0.744979	validation_1-auc:0.744563
# [357]	validation_0-auc:0.745005	validation_1-auc:0.744594
# [358]	validation_0-auc:0.745035	validation_1-auc:0.744631
# [359]	validation_0-auc:0.74531	validation_1-auc:0.74495
# [360]	validation_0-auc:0.745719	validation_1-auc:0.745399
# [361]	validation_0-auc:0.74583	validation_1-auc:0.745474
# [362]	validation_0-auc:0.745901	validation_1-auc:0.745514
# [363]	validation_0-auc:0.745924	validation_1-auc:0.745529
# [364]	validation_0-auc:0.746221	validation_1-auc:0.745791
# [365]	validation_0-auc:0.746739	validation_1-auc:0.746338
# [366]	validation_0-auc:0.747096	validation_1-auc:0.7467
# [367]	validation_0-auc:0.747432	validation_1-auc:0.747078
# [368]	validation_0-auc:0.747426	validation_1-auc:0.747072
# [369]	validation_0-auc:0.747391	validation_1-auc:0.747062
# [370]	validation_0-auc:0.74739	validation_1-auc:0.747069
# [371]	validation_0-auc:0.747524	validation_1-auc:0.747141
# [372]	validation_0-auc:0.747739	validation_1-auc:0.747324
# [373]	validation_0-auc:0.747855	validation_1-auc:0.747443
# [374]	validation_0-auc:0.747882	validation_1-auc:0.747459
# [375]	validation_0-auc:0.747937	validation_1-auc:0.747531
# [376]	validation_0-auc:0.748215	validation_1-auc:0.747848
# [377]	validation_0-auc:0.748247	validation_1-auc:0.74785
# [378]	validation_0-auc:0.748624	validation_1-auc:0.748275
# [379]	validation_0-auc:0.748773	validation_1-auc:0.74842
# [380]	validation_0-auc:0.749021	validation_1-auc:0.748655
# [381]	validation_0-auc:0.749457	validation_1-auc:0.749112
# [382]	validation_0-auc:0.749473	validation_1-auc:0.749132
# [383]	validation_0-auc:0.74982	validation_1-auc:0.749502
# [384]	validation_0-auc:0.749815	validation_1-auc:0.749498
# [385]	validation_0-auc:0.749956	validation_1-auc:0.749613
# [386]	validation_0-auc:0.750078	validation_1-auc:0.74974
# [387]	validation_0-auc:0.750297	validation_1-auc:0.749932
# [388]	validation_0-auc:0.750601	validation_1-auc:0.750214
# [389]	validation_0-auc:0.751045	validation_1-auc:0.750682
# [390]	validation_0-auc:0.751386	validation_1-auc:0.751055
# [391]	validation_0-auc:0.751727	validation_1-auc:0.751375
# [392]	validation_0-auc:0.751908	validation_1-auc:0.751593
# [393]	validation_0-auc:0.751924	validation_1-auc:0.751615
# [394]	validation_0-auc:0.752032	validation_1-auc:0.751677
# [395]	validation_0-auc:0.752102	validation_1-auc:0.751745
# [396]	validation_0-auc:0.752148	validation_1-auc:0.751802
# [397]	validation_0-auc:0.752663	validation_1-auc:0.752349
# [398]	validation_0-auc:0.752615	validation_1-auc:0.752277
# [399]	validation_0-auc:0.752794	validation_1-auc:0.752447
# [400]	validation_0-auc:0.752981	validation_1-auc:0.752625
# [401]	validation_0-auc:0.753068	validation_1-auc:0.752681
# [402]	validation_0-auc:0.75307	validation_1-auc:0.752684
# [403]	validation_0-auc:0.753245	validation_1-auc:0.752881
# [404]	validation_0-auc:0.753367	validation_1-auc:0.752974
# [405]	validation_0-auc:0.753444	validation_1-auc:0.753024
# [406]	validation_0-auc:0.753586	validation_1-auc:0.753156
# [407]	validation_0-auc:0.753725	validation_1-auc:0.753286
# [408]	validation_0-auc:0.753768	validation_1-auc:0.753323
# [409]	validation_0-auc:0.753758	validation_1-auc:0.753313
# [410]	validation_0-auc:0.753893	validation_1-auc:0.753419
# [411]	validation_0-auc:0.753936	validation_1-auc:0.75346
# [412]	validation_0-auc:0.753982	validation_1-auc:0.753515
# [413]	validation_0-auc:0.753983	validation_1-auc:0.753495
# [414]	validation_0-auc:0.754019	validation_1-auc:0.753518
# [415]	validation_0-auc:0.754007	validation_1-auc:0.75351
# [416]	validation_0-auc:0.754004	validation_1-auc:0.753508
# [417]	validation_0-auc:0.75446	validation_1-auc:0.753998
# [418]	validation_0-auc:0.754608	validation_1-auc:0.754174
# [419]	validation_0-auc:0.754832	validation_1-auc:0.754405
# [420]	validation_0-auc:0.754872	validation_1-auc:0.754445
# [421]	validation_0-auc:0.755063	validation_1-auc:0.754638
# [422]	validation_0-auc:0.755316	validation_1-auc:0.754878
# [423]	validation_0-auc:0.755393	validation_1-auc:0.754959
# [424]	validation_0-auc:0.755538	validation_1-auc:0.755073
# [425]	validation_0-auc:0.755595	validation_1-auc:0.755121
# [426]	validation_0-auc:0.755584	validation_1-auc:0.755112
# [427]	validation_0-auc:0.755645	validation_1-auc:0.755184
# [428]	validation_0-auc:0.755871	validation_1-auc:0.755402
# [429]	validation_0-auc:0.755917	validation_1-auc:0.755432
# [430]	validation_0-auc:0.755905	validation_1-auc:0.755421
# [431]	validation_0-auc:0.755892	validation_1-auc:0.755408
# [432]	validation_0-auc:0.756001	validation_1-auc:0.75552
# [433]	validation_0-auc:0.756044	validation_1-auc:0.755556
# [434]	validation_0-auc:0.756208	validation_1-auc:0.755699
# [435]	validation_0-auc:0.75642	validation_1-auc:0.755922
# [436]	validation_0-auc:0.756565	validation_1-auc:0.756077
# [437]	validation_0-auc:0.756725	validation_1-auc:0.756232
# [438]	validation_0-auc:0.756826	validation_1-auc:0.756336
# [439]	validation_0-auc:0.757007	validation_1-auc:0.756506
# [440]	validation_0-auc:0.757251	validation_1-auc:0.756776
# [441]	validation_0-auc:0.757394	validation_1-auc:0.756917
# [442]	validation_0-auc:0.757386	validation_1-auc:0.756904
# [443]	validation_0-auc:0.75749	validation_1-auc:0.757016
# [444]	validation_0-auc:0.757595	validation_1-auc:0.757118
# [445]	validation_0-auc:0.757754	validation_1-auc:0.757292
# [446]	validation_0-auc:0.758169	validation_1-auc:0.757657
# [447]	validation_0-auc:0.758192	validation_1-auc:0.757678
# [448]	validation_0-auc:0.758265	validation_1-auc:0.757765
# [449]	validation_0-auc:0.758353	validation_1-auc:0.757843
# [450]	validation_0-auc:0.758557	validation_1-auc:0.75808
# [451]	validation_0-auc:0.758665	validation_1-auc:0.75816
# [452]	validation_0-auc:0.758675	validation_1-auc:0.758172
# [453]	validation_0-auc:0.759106	validation_1-auc:0.758633
# [454]	validation_0-auc:0.759251	validation_1-auc:0.758758
# [455]	validation_0-auc:0.759303	validation_1-auc:0.758803
# [456]	validation_0-auc:0.759301	validation_1-auc:0.758786
# [457]	validation_0-auc:0.759515	validation_1-auc:0.759009
# [458]	validation_0-auc:0.759784	validation_1-auc:0.759285
# [459]	validation_0-auc:0.759856	validation_1-auc:0.759338
# [460]	validation_0-auc:0.759889	validation_1-auc:0.759373
# [461]	validation_0-auc:0.759944	validation_1-auc:0.759445
# [462]	validation_0-auc:0.76013	validation_1-auc:0.759645
# [463]	validation_0-auc:0.760242	validation_1-auc:0.759745
# [464]	validation_0-auc:0.760278	validation_1-auc:0.759777
# [465]	validation_0-auc:0.760264	validation_1-auc:0.759767
# [466]	validation_0-auc:0.760256	validation_1-auc:0.759759
# [467]	validation_0-auc:0.760259	validation_1-auc:0.759764
# [468]	validation_0-auc:0.760284	validation_1-auc:0.759787
# [469]	validation_0-auc:0.760292	validation_1-auc:0.759794
# [470]	validation_0-auc:0.760568	validation_1-auc:0.760061
# [471]	validation_0-auc:0.760813	validation_1-auc:0.760225
# [472]	validation_0-auc:0.760922	validation_1-auc:0.760334
# [473]	validation_0-auc:0.761237	validation_1-auc:0.760585
# [474]	validation_0-auc:0.76141	validation_1-auc:0.760772
# [475]	validation_0-auc:0.761569	validation_1-auc:0.760938
# [476]	validation_0-auc:0.761553	validation_1-auc:0.760914
# [477]	validation_0-auc:0.76167	validation_1-auc:0.761019
# [478]	validation_0-auc:0.761676	validation_1-auc:0.761003
# [479]	validation_0-auc:0.76178	validation_1-auc:0.761104
# [480]	validation_0-auc:0.761793	validation_1-auc:0.761117
# [481]	validation_0-auc:0.761915	validation_1-auc:0.76124
# [482]	validation_0-auc:0.761933	validation_1-auc:0.761272
# [483]	validation_0-auc:0.762131	validation_1-auc:0.761502
# [484]	validation_0-auc:0.762406	validation_1-auc:0.761702
# [485]	validation_0-auc:0.76244	validation_1-auc:0.761739
# [486]	validation_0-auc:0.762438	validation_1-auc:0.761759
# [487]	validation_0-auc:0.762435	validation_1-auc:0.761757
# [488]	validation_0-auc:0.762704	validation_1-auc:0.762026
# [489]	validation_0-auc:0.762873	validation_1-auc:0.762172
# [490]	validation_0-auc:0.762984	validation_1-auc:0.762286
# [491]	validation_0-auc:0.763234	validation_1-auc:0.762553
# [492]	validation_0-auc:0.763546	validation_1-auc:0.762864
# [493]	validation_0-auc:0.763581	validation_1-auc:0.762895
# [494]	validation_0-auc:0.763659	validation_1-auc:0.762973
# [495]	validation_0-auc:0.763811	validation_1-auc:0.763111
# [496]	validation_0-auc:0.763815	validation_1-auc:0.76311
# [497]	validation_0-auc:0.763835	validation_1-auc:0.763134
# [498]	validation_0-auc:0.763956	validation_1-auc:0.763268
# [499]	validation_0-auc:0.763975	validation_1-auc:0.763278
# [500]	validation_0-auc:0.764017	validation_1-auc:0.76331
# [501]	validation_0-auc:0.764235	validation_1-auc:0.763523
# [502]	validation_0-auc:0.764315	validation_1-auc:0.763563
# [503]	validation_0-auc:0.764599	validation_1-auc:0.763841
# [504]	validation_0-auc:0.764703	validation_1-auc:0.763928
# [505]	validation_0-auc:0.764781	validation_1-auc:0.764002
# [506]	validation_0-auc:0.764934	validation_1-auc:0.764182
# [507]	validation_0-auc:0.765175	validation_1-auc:0.764411
# [508]	validation_0-auc:0.765204	validation_1-auc:0.764438
# [509]	validation_0-auc:0.765267	validation_1-auc:0.764491
# [510]	validation_0-auc:0.76546	validation_1-auc:0.764709
# [511]	validation_0-auc:0.765659	validation_1-auc:0.764895
# [512]	validation_0-auc:0.76591	validation_1-auc:0.765133
# [513]	validation_0-auc:0.765923	validation_1-auc:0.765146
# [514]	validation_0-auc:0.76601	validation_1-auc:0.765213
# [515]	validation_0-auc:0.766177	validation_1-auc:0.765349
# [516]	validation_0-auc:0.76616	validation_1-auc:0.765319
# [517]	validation_0-auc:0.76635	validation_1-auc:0.765454
# [518]	validation_0-auc:0.766634	validation_1-auc:0.765702
# [519]	validation_0-auc:0.766745	validation_1-auc:0.765835
# [520]	validation_0-auc:0.766795	validation_1-auc:0.765875
# [521]	validation_0-auc:0.766848	validation_1-auc:0.765926
# [522]	validation_0-auc:0.76684	validation_1-auc:0.765916
# [523]	validation_0-auc:0.766892	validation_1-auc:0.765987
# [524]	validation_0-auc:0.76694	validation_1-auc:0.766027
# [525]	validation_0-auc:0.767182	validation_1-auc:0.766277
# [526]	validation_0-auc:0.767536	validation_1-auc:0.76665
# [527]	validation_0-auc:0.767592	validation_1-auc:0.766732
# [528]	validation_0-auc:0.767724	validation_1-auc:0.766831
# [529]	validation_0-auc:0.767855	validation_1-auc:0.766943
# [530]	validation_0-auc:0.767878	validation_1-auc:0.766968
# [531]	validation_0-auc:0.767984	validation_1-auc:0.767098
# [532]	validation_0-auc:0.767999	validation_1-auc:0.767125
# [533]	validation_0-auc:0.768074	validation_1-auc:0.767182
# [534]	validation_0-auc:0.76821	validation_1-auc:0.767332
# [535]	validation_0-auc:0.768229	validation_1-auc:0.767348
# [536]	validation_0-auc:0.768315	validation_1-auc:0.767434
# [537]	validation_0-auc:0.768362	validation_1-auc:0.767459
# [538]	validation_0-auc:0.768749	validation_1-auc:0.76785
# [539]	validation_0-auc:0.768775	validation_1-auc:0.767875
# [540]	validation_0-auc:0.768921	validation_1-auc:0.768024
# [541]	validation_0-auc:0.768981	validation_1-auc:0.768081
# [542]	validation_0-auc:0.769239	validation_1-auc:0.768316
# [543]	validation_0-auc:0.769459	validation_1-auc:0.768536
# [544]	validation_0-auc:0.769824	validation_1-auc:0.768883
# [545]	validation_0-auc:0.769825	validation_1-auc:0.768885
# [546]	validation_0-auc:0.770016	validation_1-auc:0.769053
# [547]	validation_0-auc:0.770005	validation_1-auc:0.769039
# [548]	validation_0-auc:0.770288	validation_1-auc:0.76931
# [549]	validation_0-auc:0.770458	validation_1-auc:0.769486
# [550]	validation_0-auc:0.770544	validation_1-auc:0.769559
# [551]	validation_0-auc:0.77055	validation_1-auc:0.769561
# [552]	validation_0-auc:0.770863	validation_1-auc:0.76986
# [553]	validation_0-auc:0.770891	validation_1-auc:0.769877
# [554]	validation_0-auc:0.770943	validation_1-auc:0.769929
# [555]	validation_0-auc:0.770969	validation_1-auc:0.769953
# [556]	validation_0-auc:0.77119	validation_1-auc:0.77021
# [557]	validation_0-auc:0.771221	validation_1-auc:0.77023
# [558]	validation_0-auc:0.771306	validation_1-auc:0.770313
# [559]	validation_0-auc:0.771399	validation_1-auc:0.770407
# [560]	validation_0-auc:0.771478	validation_1-auc:0.770471
# [561]	validation_0-auc:0.77155	validation_1-auc:0.770532
# [562]	validation_0-auc:0.771717	validation_1-auc:0.770704
# [563]	validation_0-auc:0.771887	validation_1-auc:0.770871
# [564]	validation_0-auc:0.77198	validation_1-auc:0.770948
# [565]	validation_0-auc:0.771991	validation_1-auc:0.770958
# [566]	validation_0-auc:0.772216	validation_1-auc:0.771196
# [567]	validation_0-auc:0.772223	validation_1-auc:0.771199
# [568]	validation_0-auc:0.772253	validation_1-auc:0.771228
# [569]	validation_0-auc:0.772257	validation_1-auc:0.771231
# [570]	validation_0-auc:0.772277	validation_1-auc:0.771253
# [571]	validation_0-auc:0.772385	validation_1-auc:0.771347
# [572]	validation_0-auc:0.772394	validation_1-auc:0.771357
# [573]	validation_0-auc:0.772395	validation_1-auc:0.771358
# [574]	validation_0-auc:0.772466	validation_1-auc:0.771432
# [575]	validation_0-auc:0.772544	validation_1-auc:0.771511
# [576]	validation_0-auc:0.772568	validation_1-auc:0.771538
# [577]	validation_0-auc:0.772694	validation_1-auc:0.771649
# [578]	validation_0-auc:0.77289	validation_1-auc:0.771799
# [579]	validation_0-auc:0.773184	validation_1-auc:0.77211
# [580]	validation_0-auc:0.773333	validation_1-auc:0.772262
# [581]	validation_0-auc:0.773571	validation_1-auc:0.77249
# [582]	validation_0-auc:0.773653	validation_1-auc:0.772572
# [583]	validation_0-auc:0.773825	validation_1-auc:0.772733
# [584]	validation_0-auc:0.773936	validation_1-auc:0.772864
# [585]	validation_0-auc:0.774085	validation_1-auc:0.77297
# [586]	validation_0-auc:0.774347	validation_1-auc:0.773178
# [587]	validation_0-auc:0.77444	validation_1-auc:0.773266
# [588]	validation_0-auc:0.774668	validation_1-auc:0.773543
# [589]	validation_0-auc:0.774888	validation_1-auc:0.77379
# [590]	validation_0-auc:0.775098	validation_1-auc:0.773981
# [591]	validation_0-auc:0.775146	validation_1-auc:0.774017
# [592]	validation_0-auc:0.775195	validation_1-auc:0.774053
# [593]	validation_0-auc:0.775486	validation_1-auc:0.774306
# [594]	validation_0-auc:0.775632	validation_1-auc:0.774485
# [595]	validation_0-auc:0.775709	validation_1-auc:0.774563
# [596]	validation_0-auc:0.775705	validation_1-auc:0.774559
# [597]	validation_0-auc:0.775842	validation_1-auc:0.774682
# [598]	validation_0-auc:0.775996	validation_1-auc:0.774822
# [599]	validation_0-auc:0.776032	validation_1-auc:0.774846
# [600]	validation_0-auc:0.776028	validation_1-auc:0.774832
# [601]	validation_0-auc:0.776277	validation_1-auc:0.775078
# [602]	validation_0-auc:0.776363	validation_1-auc:0.775174
# [603]	validation_0-auc:0.776676	validation_1-auc:0.775462
# [604]	validation_0-auc:0.776732	validation_1-auc:0.775528
# [605]	validation_0-auc:0.776847	validation_1-auc:0.775644
# [606]	validation_0-auc:0.776867	validation_1-auc:0.775655
# [607]	validation_0-auc:0.776957	validation_1-auc:0.775747
# [608]	validation_0-auc:0.777018	validation_1-auc:0.775803
# [609]	validation_0-auc:0.77713	validation_1-auc:0.775925
# [610]	validation_0-auc:0.777171	validation_1-auc:0.77594
# [611]	validation_0-auc:0.777274	validation_1-auc:0.776032
# [612]	validation_0-auc:0.777421	validation_1-auc:0.776176
# [613]	validation_0-auc:0.77754	validation_1-auc:0.77629
# [614]	validation_0-auc:0.777711	validation_1-auc:0.776456
# [615]	validation_0-auc:0.777771	validation_1-auc:0.776517
# [616]	validation_0-auc:0.7779	validation_1-auc:0.776676
# [617]	validation_0-auc:0.778015	validation_1-auc:0.776783
# [618]	validation_0-auc:0.778091	validation_1-auc:0.776859
# [619]	validation_0-auc:0.778204	validation_1-auc:0.776995
# [620]	validation_0-auc:0.778225	validation_1-auc:0.77701
# [621]	validation_0-auc:0.778295	validation_1-auc:0.77707
# [622]	validation_0-auc:0.77842	validation_1-auc:0.777199
# [623]	validation_0-auc:0.778502	validation_1-auc:0.777299
# [624]	validation_0-auc:0.7786	validation_1-auc:0.77742
# [625]	validation_0-auc:0.778641	validation_1-auc:0.777435
# [626]	validation_0-auc:0.778753	validation_1-auc:0.777548
# [627]	validation_0-auc:0.77876	validation_1-auc:0.777553
# [628]	validation_0-auc:0.778791	validation_1-auc:0.777573
# [629]	validation_0-auc:0.778794	validation_1-auc:0.777575
# [630]	validation_0-auc:0.778966	validation_1-auc:0.777709
# [631]	validation_0-auc:0.779117	validation_1-auc:0.777898
# [632]	validation_0-auc:0.779177	validation_1-auc:0.777946
# [633]	validation_0-auc:0.77917	validation_1-auc:0.777944
# [634]	validation_0-auc:0.779546	validation_1-auc:0.778358
# [635]	validation_0-auc:0.779718	validation_1-auc:0.778535
# [636]	validation_0-auc:0.77988	validation_1-auc:0.778713
# [637]	validation_0-auc:0.780106	validation_1-auc:0.778922
# [638]	validation_0-auc:0.780149	validation_1-auc:0.778963
# [639]	validation_0-auc:0.780191	validation_1-auc:0.778974
# [640]	validation_0-auc:0.78042	validation_1-auc:0.779175
# [641]	validation_0-auc:0.780502	validation_1-auc:0.779248
# [642]	validation_0-auc:0.780554	validation_1-auc:0.779337
# [643]	validation_0-auc:0.780842	validation_1-auc:0.779606
# [644]	validation_0-auc:0.780884	validation_1-auc:0.779662
# [645]	validation_0-auc:0.780919	validation_1-auc:0.779687
# [646]	validation_0-auc:0.781036	validation_1-auc:0.779804
# [647]	validation_0-auc:0.781079	validation_1-auc:0.779823
# [648]	validation_0-auc:0.781243	validation_1-auc:0.780021
# [649]	validation_0-auc:0.781311	validation_1-auc:0.780092
# [650]	validation_0-auc:0.78153	validation_1-auc:0.780333
# [651]	validation_0-auc:0.781844	validation_1-auc:0.780633
# [652]	validation_0-auc:0.782053	validation_1-auc:0.780841
# [653]	validation_0-auc:0.782166	validation_1-auc:0.780987
# [654]	validation_0-auc:0.782393	validation_1-auc:0.781209
# [655]	validation_0-auc:0.782617	validation_1-auc:0.781465
# [656]	validation_0-auc:0.782838	validation_1-auc:0.781737
# [657]	validation_0-auc:0.782972	validation_1-auc:0.781892
# [658]	validation_0-auc:0.783008	validation_1-auc:0.781948
# [659]	validation_0-auc:0.783086	validation_1-auc:0.782009
# [660]	validation_0-auc:0.783176	validation_1-auc:0.782122
# [661]	validation_0-auc:0.783236	validation_1-auc:0.782186
# [662]	validation_0-auc:0.783344	validation_1-auc:0.782293
# [663]	validation_0-auc:0.783379	validation_1-auc:0.782318
# [664]	validation_0-auc:0.783595	validation_1-auc:0.782552
# [665]	validation_0-auc:0.783626	validation_1-auc:0.782577
# [666]	validation_0-auc:0.783804	validation_1-auc:0.782758
# [667]	validation_0-auc:0.783849	validation_1-auc:0.782797
# [668]	validation_0-auc:0.784114	validation_1-auc:0.783045
# [669]	validation_0-auc:0.78419	validation_1-auc:0.783129
# [670]	validation_0-auc:0.784197	validation_1-auc:0.783136
# [671]	validation_0-auc:0.784194	validation_1-auc:0.783133
# [672]	validation_0-auc:0.784201	validation_1-auc:0.783143
# [673]	validation_0-auc:0.784254	validation_1-auc:0.783182
# [674]	validation_0-auc:0.784407	validation_1-auc:0.783353
# [675]	validation_0-auc:0.784468	validation_1-auc:0.783423
# [676]	validation_0-auc:0.784471	validation_1-auc:0.783425
# [677]	validation_0-auc:0.784627	validation_1-auc:0.783566
# [678]	validation_0-auc:0.784848	validation_1-auc:0.783818
# [679]	validation_0-auc:0.784947	validation_1-auc:0.783896
# [680]	validation_0-auc:0.784953	validation_1-auc:0.783904
# [681]	validation_0-auc:0.784991	validation_1-auc:0.783947
# [682]	validation_0-auc:0.784991	validation_1-auc:0.783948
# [683]	validation_0-auc:0.785007	validation_1-auc:0.78396
# [684]	validation_0-auc:0.785045	validation_1-auc:0.784007
# [685]	validation_0-auc:0.785057	validation_1-auc:0.784012
# [686]	validation_0-auc:0.785056	validation_1-auc:0.784011
# [687]	validation_0-auc:0.785115	validation_1-auc:0.784045
# [688]	validation_0-auc:0.78512	validation_1-auc:0.784048
# [689]	validation_0-auc:0.785294	validation_1-auc:0.784205
# [690]	validation_0-auc:0.785291	validation_1-auc:0.784205
# [691]	validation_0-auc:0.78533	validation_1-auc:0.784249
# [692]	validation_0-auc:0.78533	validation_1-auc:0.784246
# [693]	validation_0-auc:0.785332	validation_1-auc:0.784245
# [694]	validation_0-auc:0.785333	validation_1-auc:0.784246
# [695]	validation_0-auc:0.785449	validation_1-auc:0.784342
# [696]	validation_0-auc:0.785466	validation_1-auc:0.784354
# [697]	validation_0-auc:0.785469	validation_1-auc:0.784358
# [698]	validation_0-auc:0.7855	validation_1-auc:0.784386
# [699]	validation_0-auc:0.785725	validation_1-auc:0.784609
# [700]	validation_0-auc:0.785783	validation_1-auc:0.784666
# [701]	validation_0-auc:0.785808	validation_1-auc:0.784688
# [702]	validation_0-auc:0.785866	validation_1-auc:0.784765
# [703]	validation_0-auc:0.785918	validation_1-auc:0.78479
# [704]	validation_0-auc:0.786044	validation_1-auc:0.784897
# [705]	validation_0-auc:0.786164	validation_1-auc:0.784994
# [706]	validation_0-auc:0.786358	validation_1-auc:0.785171
# [707]	validation_0-auc:0.786647	validation_1-auc:0.785425
# [708]	validation_0-auc:0.786657	validation_1-auc:0.785433
# [709]	validation_0-auc:0.786723	validation_1-auc:0.785501
# [710]	validation_0-auc:0.78681	validation_1-auc:0.785588
# [711]	validation_0-auc:0.786958	validation_1-auc:0.785718
# [712]	validation_0-auc:0.786978	validation_1-auc:0.785737
# [713]	validation_0-auc:0.787167	validation_1-auc:0.785919
# [714]	validation_0-auc:0.787421	validation_1-auc:0.786191
# [715]	validation_0-auc:0.787716	validation_1-auc:0.786451
# [716]	validation_0-auc:0.787769	validation_1-auc:0.786491
# [717]	validation_0-auc:0.78806	validation_1-auc:0.786773
# [718]	validation_0-auc:0.788106	validation_1-auc:0.786817
# [719]	validation_0-auc:0.788136	validation_1-auc:0.786841
# [720]	validation_0-auc:0.788184	validation_1-auc:0.786875
# [721]	validation_0-auc:0.788252	validation_1-auc:0.786946
# [722]	validation_0-auc:0.788251	validation_1-auc:0.786944
# [723]	validation_0-auc:0.788326	validation_1-auc:0.787008
# [724]	validation_0-auc:0.78835	validation_1-auc:0.787033
# [725]	validation_0-auc:0.788637	validation_1-auc:0.787278
# [726]	validation_0-auc:0.788678	validation_1-auc:0.787331
# [727]	validation_0-auc:0.788766	validation_1-auc:0.787403
# [728]	validation_0-auc:0.78885	validation_1-auc:0.787467
# [729]	validation_0-auc:0.788925	validation_1-auc:0.787536
# [730]	validation_0-auc:0.788987	validation_1-auc:0.787583
# [731]	validation_0-auc:0.788992	validation_1-auc:0.787589
# [732]	validation_0-auc:0.78912	validation_1-auc:0.787698
# [733]	validation_0-auc:0.78921	validation_1-auc:0.787789
# [734]	validation_0-auc:0.789278	validation_1-auc:0.787845
# [735]	validation_0-auc:0.789283	validation_1-auc:0.787848
# [736]	validation_0-auc:0.789294	validation_1-auc:0.78786
# [737]	validation_0-auc:0.789295	validation_1-auc:0.78786
# [738]	validation_0-auc:0.789447	validation_1-auc:0.788018
# [739]	validation_0-auc:0.789489	validation_1-auc:0.788047
# [740]	validation_0-auc:0.789523	validation_1-auc:0.788075
# [741]	validation_0-auc:0.789523	validation_1-auc:0.788076
# [742]	validation_0-auc:0.789533	validation_1-auc:0.788086
# [743]	validation_0-auc:0.789561	validation_1-auc:0.7881
# [744]	validation_0-auc:0.789585	validation_1-auc:0.788119
# [745]	validation_0-auc:0.789849	validation_1-auc:0.788406
# [746]	validation_0-auc:0.789826	validation_1-auc:0.788371
# [747]	validation_0-auc:0.789964	validation_1-auc:0.788528
# [748]	validation_0-auc:0.790026	validation_1-auc:0.788592
# [749]	validation_0-auc:0.790153	validation_1-auc:0.788718
# [750]	validation_0-auc:0.790192	validation_1-auc:0.788752
# [751]	validation_0-auc:0.790259	validation_1-auc:0.788851
# [752]	validation_0-auc:0.790441	validation_1-auc:0.788986
# [753]	validation_0-auc:0.790481	validation_1-auc:0.789011
# [754]	validation_0-auc:0.790524	validation_1-auc:0.78906
# [755]	validation_0-auc:0.790577	validation_1-auc:0.789083
# [756]	validation_0-auc:0.790624	validation_1-auc:0.789135
# [757]	validation_0-auc:0.790667	validation_1-auc:0.789173
# [758]	validation_0-auc:0.790941	validation_1-auc:0.789451
# [759]	validation_0-auc:0.791014	validation_1-auc:0.78952
# [760]	validation_0-auc:0.791151	validation_1-auc:0.789634
# [761]	validation_0-auc:0.791373	validation_1-auc:0.789845
# [762]	validation_0-auc:0.791407	validation_1-auc:0.789867
# [763]	validation_0-auc:0.791434	validation_1-auc:0.789901
# [764]	validation_0-auc:0.791449	validation_1-auc:0.78988
# [765]	validation_0-auc:0.791633	validation_1-auc:0.790025
# [766]	validation_0-auc:0.791683	validation_1-auc:0.790076
# [767]	validation_0-auc:0.791775	validation_1-auc:0.790175
# [768]	validation_0-auc:0.791818	validation_1-auc:0.790211
# [769]	validation_0-auc:0.791985	validation_1-auc:0.790371
# [770]	validation_0-auc:0.792058	validation_1-auc:0.790436
# [771]	validation_0-auc:0.792137	validation_1-auc:0.790484
# [772]	validation_0-auc:0.792223	validation_1-auc:0.790569
# [773]	validation_0-auc:0.792224	validation_1-auc:0.790569
# [774]	validation_0-auc:0.792265	validation_1-auc:0.790613
# [775]	validation_0-auc:0.792269	validation_1-auc:0.790616
# [776]	validation_0-auc:0.792335	validation_1-auc:0.790682
# [777]	validation_0-auc:0.792359	validation_1-auc:0.790713
# [778]	validation_0-auc:0.792399	validation_1-auc:0.790741
# [779]	validation_0-auc:0.79247	validation_1-auc:0.790809
# [780]	validation_0-auc:0.792515	validation_1-auc:0.790848
# [781]	validation_0-auc:0.792478	validation_1-auc:0.790807
# [782]	validation_0-auc:0.792586	validation_1-auc:0.790931
# [783]	validation_0-auc:0.792601	validation_1-auc:0.790946
# [784]	validation_0-auc:0.792631	validation_1-auc:0.790965
# [785]	validation_0-auc:0.79279	validation_1-auc:0.791088
# [786]	validation_0-auc:0.792817	validation_1-auc:0.79112
# [787]	validation_0-auc:0.792894	validation_1-auc:0.791182
# [788]	validation_0-auc:0.792956	validation_1-auc:0.791225
# [789]	validation_0-auc:0.793078	validation_1-auc:0.791358
# [790]	validation_0-auc:0.793289	validation_1-auc:0.791611
# [791]	validation_0-auc:0.793387	validation_1-auc:0.791715
# [792]	validation_0-auc:0.793518	validation_1-auc:0.79187
# [793]	validation_0-auc:0.793614	validation_1-auc:0.791949
# [794]	validation_0-auc:0.793614	validation_1-auc:0.791949
# [795]	validation_0-auc:0.793724	validation_1-auc:0.792046
# [796]	validation_0-auc:0.793795	validation_1-auc:0.792121
# [797]	validation_0-auc:0.79385	validation_1-auc:0.792164
# [798]	validation_0-auc:0.79385	validation_1-auc:0.792164
# [799]	validation_0-auc:0.794043	validation_1-auc:0.79239
# [800]	validation_0-auc:0.794055	validation_1-auc:0.792404
# [801]	validation_0-auc:0.79416	validation_1-auc:0.792481
# [802]	validation_0-auc:0.794186	validation_1-auc:0.792496
# [803]	validation_0-auc:0.794382	validation_1-auc:0.792701
# [804]	validation_0-auc:0.794391	validation_1-auc:0.792712
# [805]	validation_0-auc:0.794391	validation_1-auc:0.792712
# [806]	validation_0-auc:0.794391	validation_1-auc:0.792712
# [807]	validation_0-auc:0.794409	validation_1-auc:0.792698
# [808]	validation_0-auc:0.79441	validation_1-auc:0.7927
# [809]	validation_0-auc:0.794528	validation_1-auc:0.792848
# [810]	validation_0-auc:0.794568	validation_1-auc:0.792887
# [811]	validation_0-auc:0.794566	validation_1-auc:0.792885
# [812]	validation_0-auc:0.794568	validation_1-auc:0.792885
# [813]	validation_0-auc:0.794752	validation_1-auc:0.793077
# [814]	validation_0-auc:0.794768	validation_1-auc:0.793081
# [815]	validation_0-auc:0.794768	validation_1-auc:0.793081
# [816]	validation_0-auc:0.794804	validation_1-auc:0.793109
# [817]	validation_0-auc:0.794807	validation_1-auc:0.793101
# [818]	validation_0-auc:0.794853	validation_1-auc:0.793138
# [819]	validation_0-auc:0.794862	validation_1-auc:0.793148
# [820]	validation_0-auc:0.794876	validation_1-auc:0.793163
# [821]	validation_0-auc:0.794998	validation_1-auc:0.793297
# [822]	validation_0-auc:0.795024	validation_1-auc:0.793326
# [823]	validation_0-auc:0.795025	validation_1-auc:0.793327
# [824]	validation_0-auc:0.795153	validation_1-auc:0.793439
# [825]	validation_0-auc:0.795229	validation_1-auc:0.793506
# [826]	validation_0-auc:0.795316	validation_1-auc:0.793591
# [827]	validation_0-auc:0.795402	validation_1-auc:0.793664
# [828]	validation_0-auc:0.795442	validation_1-auc:0.793701
# [829]	validation_0-auc:0.795443	validation_1-auc:0.793702
# [830]	validation_0-auc:0.795508	validation_1-auc:0.793763
# [831]	validation_0-auc:0.795517	validation_1-auc:0.793777
# [832]	validation_0-auc:0.795522	validation_1-auc:0.793783
# [833]	validation_0-auc:0.795654	validation_1-auc:0.793871
# [834]	validation_0-auc:0.795727	validation_1-auc:0.793954
# [835]	validation_0-auc:0.795887	validation_1-auc:0.794129
# [836]	validation_0-auc:0.795973	validation_1-auc:0.79421
# [837]	validation_0-auc:0.796001	validation_1-auc:0.794245
# [838]	validation_0-auc:0.796096	validation_1-auc:0.794338
# [839]	validation_0-auc:0.796156	validation_1-auc:0.79438
# [840]	validation_0-auc:0.796242	validation_1-auc:0.794439
# [841]	validation_0-auc:0.796268	validation_1-auc:0.79446
# [842]	validation_0-auc:0.796323	validation_1-auc:0.794504
# [843]	validation_0-auc:0.796436	validation_1-auc:0.794623
# [844]	validation_0-auc:0.796574	validation_1-auc:0.794786
# [845]	validation_0-auc:0.796656	validation_1-auc:0.794864
# [846]	validation_0-auc:0.796711	validation_1-auc:0.794904
# [847]	validation_0-auc:0.796899	validation_1-auc:0.79511
# [848]	validation_0-auc:0.797004	validation_1-auc:0.795153
# [849]	validation_0-auc:0.797068	validation_1-auc:0.795204
# [850]	validation_0-auc:0.797119	validation_1-auc:0.795231
# [851]	validation_0-auc:0.797304	validation_1-auc:0.795414
# [852]	validation_0-auc:0.797427	validation_1-auc:0.795549
# [853]	validation_0-auc:0.797755	validation_1-auc:0.795886
# [854]	validation_0-auc:0.797778	validation_1-auc:0.795913
# [855]	validation_0-auc:0.797883	validation_1-auc:0.796053
# [856]	validation_0-auc:0.797919	validation_1-auc:0.796091
# [857]	validation_0-auc:0.797923	validation_1-auc:0.796126
# [858]	validation_0-auc:0.797986	validation_1-auc:0.796177
# [859]	validation_0-auc:0.798095	validation_1-auc:0.796272
# [860]	validation_0-auc:0.798195	validation_1-auc:0.7964
# [861]	validation_0-auc:0.798253	validation_1-auc:0.796442
# [862]	validation_0-auc:0.798284	validation_1-auc:0.796485
# [863]	validation_0-auc:0.798325	validation_1-auc:0.79652
# [864]	validation_0-auc:0.798411	validation_1-auc:0.796657
# [865]	validation_0-auc:0.798473	validation_1-auc:0.796722
# [866]	validation_0-auc:0.798551	validation_1-auc:0.796779
# [867]	validation_0-auc:0.798542	validation_1-auc:0.796778
# [868]	validation_0-auc:0.798583	validation_1-auc:0.796813
# [869]	validation_0-auc:0.798615	validation_1-auc:0.796839
# [870]	validation_0-auc:0.79866	validation_1-auc:0.796889
# [871]	validation_0-auc:0.798669	validation_1-auc:0.7969
# [872]	validation_0-auc:0.798735	validation_1-auc:0.796957
# [873]	validation_0-auc:0.798882	validation_1-auc:0.797069
# [874]	validation_0-auc:0.798958	validation_1-auc:0.79717
# [875]	validation_0-auc:0.799022	validation_1-auc:0.797225
# [876]	validation_0-auc:0.799022	validation_1-auc:0.797226
# [877]	validation_0-auc:0.799098	validation_1-auc:0.797288
# [878]	validation_0-auc:0.799242	validation_1-auc:0.797439
# [879]	validation_0-auc:0.799417	validation_1-auc:0.797615
# [880]	validation_0-auc:0.799594	validation_1-auc:0.79779
# [881]	validation_0-auc:0.799615	validation_1-auc:0.797817
# [882]	validation_0-auc:0.799695	validation_1-auc:0.797907
# [883]	validation_0-auc:0.799811	validation_1-auc:0.798034
# [884]	validation_0-auc:0.799997	validation_1-auc:0.798201
# [885]	validation_0-auc:0.799995	validation_1-auc:0.798201
# [886]	validation_0-auc:0.800008	validation_1-auc:0.798215
# [887]	validation_0-auc:0.800009	validation_1-auc:0.798216
# [888]	validation_0-auc:0.800021	validation_1-auc:0.798237
# [889]	validation_0-auc:0.800035	validation_1-auc:0.798259
# [890]	validation_0-auc:0.800056	validation_1-auc:0.798292
# [891]	validation_0-auc:0.800097	validation_1-auc:0.798347
# [892]	validation_0-auc:0.800095	validation_1-auc:0.798347
# [893]	validation_0-auc:0.800175	validation_1-auc:0.798409
# [894]	validation_0-auc:0.800175	validation_1-auc:0.798409
# [895]	validation_0-auc:0.800295	validation_1-auc:0.798553
# [896]	validation_0-auc:0.800544	validation_1-auc:0.79883
# [897]	validation_0-auc:0.800603	validation_1-auc:0.798886
# [898]	validation_0-auc:0.800659	validation_1-auc:0.798934
# [899]	validation_0-auc:0.800754	validation_1-auc:0.798991
# [900]	validation_0-auc:0.800964	validation_1-auc:0.799189
# [901]	validation_0-auc:0.800962	validation_1-auc:0.799189
# [902]	validation_0-auc:0.801072	validation_1-auc:0.799301
# [903]	validation_0-auc:0.801078	validation_1-auc:0.799295
# [904]	validation_0-auc:0.801247	validation_1-auc:0.799438
# [905]	validation_0-auc:0.801276	validation_1-auc:0.799487
# [906]	validation_0-auc:0.801274	validation_1-auc:0.799487
# [907]	validation_0-auc:0.801252	validation_1-auc:0.799461
# [908]	validation_0-auc:0.801253	validation_1-auc:0.799461
# [909]	validation_0-auc:0.801339	validation_1-auc:0.799549
# [910]	validation_0-auc:0.801511	validation_1-auc:0.79974
# [911]	validation_0-auc:0.80165	validation_1-auc:0.799868
# [912]	validation_0-auc:0.801689	validation_1-auc:0.799877
# [913]	validation_0-auc:0.801764	validation_1-auc:0.799943
# [914]	validation_0-auc:0.801847	validation_1-auc:0.800018
# [915]	validation_0-auc:0.801856	validation_1-auc:0.800022
# [916]	validation_0-auc:0.802042	validation_1-auc:0.800189
# [917]	validation_0-auc:0.802125	validation_1-auc:0.800294
# [918]	validation_0-auc:0.802221	validation_1-auc:0.800387
# [919]	validation_0-auc:0.802305	validation_1-auc:0.800466
# [920]	validation_0-auc:0.802303	validation_1-auc:0.800466
# [921]	validation_0-auc:0.802293	validation_1-auc:0.800455
# [922]	validation_0-auc:0.802354	validation_1-auc:0.800517
# [923]	validation_0-auc:0.802371	validation_1-auc:0.800541
# [924]	validation_0-auc:0.802397	validation_1-auc:0.800573
# [925]	validation_0-auc:0.802475	validation_1-auc:0.800646
# [926]	validation_0-auc:0.802574	validation_1-auc:0.800743
# [927]	validation_0-auc:0.802628	validation_1-auc:0.800787
# [928]	validation_0-auc:0.802637	validation_1-auc:0.800787
# [929]	validation_0-auc:0.802657	validation_1-auc:0.80081
# [930]	validation_0-auc:0.802698	validation_1-auc:0.800847
# [931]	validation_0-auc:0.802742	validation_1-auc:0.80089
# [932]	validation_0-auc:0.802747	validation_1-auc:0.800898
# [933]	validation_0-auc:0.802758	validation_1-auc:0.800906
# [934]	validation_0-auc:0.802854	validation_1-auc:0.801042
# [935]	validation_0-auc:0.80285	validation_1-auc:0.801038
# [936]	validation_0-auc:0.80289	validation_1-auc:0.801075
# [937]	validation_0-auc:0.802995	validation_1-auc:0.801204
# [938]	validation_0-auc:0.803011	validation_1-auc:0.801212
# [939]	validation_0-auc:0.803003	validation_1-auc:0.801197
# [940]	validation_0-auc:0.803011	validation_1-auc:0.801205
# [941]	validation_0-auc:0.803047	validation_1-auc:0.801255
# [942]	validation_0-auc:0.803055	validation_1-auc:0.801258
# [943]	validation_0-auc:0.803171	validation_1-auc:0.80138
# [944]	validation_0-auc:0.803191	validation_1-auc:0.801391
# [945]	validation_0-auc:0.803232	validation_1-auc:0.801407
# [946]	validation_0-auc:0.803251	validation_1-auc:0.801426
# [947]	validation_0-auc:0.803269	validation_1-auc:0.801442
# [948]	validation_0-auc:0.803336	validation_1-auc:0.801507
# [949]	validation_0-auc:0.803408	validation_1-auc:0.801571
# [950]	validation_0-auc:0.803486	validation_1-auc:0.801636
# [951]	validation_0-auc:0.803504	validation_1-auc:0.801661
# [952]	validation_0-auc:0.803679	validation_1-auc:0.801819
# [953]	validation_0-auc:0.803732	validation_1-auc:0.801865
# [954]	validation_0-auc:0.803785	validation_1-auc:0.801925
# [955]	validation_0-auc:0.803797	validation_1-auc:0.80194
# [956]	validation_0-auc:0.80399	validation_1-auc:0.802114
# [957]	validation_0-auc:0.804071	validation_1-auc:0.80215
# [958]	validation_0-auc:0.804111	validation_1-auc:0.802179
# [959]	validation_0-auc:0.804119	validation_1-auc:0.802192
# [960]	validation_0-auc:0.804131	validation_1-auc:0.802207
# [961]	validation_0-auc:0.804124	validation_1-auc:0.802193
# [962]	validation_0-auc:0.804152	validation_1-auc:0.802222
# [963]	validation_0-auc:0.804151	validation_1-auc:0.802221
# [964]	validation_0-auc:0.804165	validation_1-auc:0.802232
# [965]	validation_0-auc:0.804388	validation_1-auc:0.802459
# [966]	validation_0-auc:0.804344	validation_1-auc:0.802433
# [967]	validation_0-auc:0.804433	validation_1-auc:0.802527
# [968]	validation_0-auc:0.804433	validation_1-auc:0.802528
# [969]	validation_0-auc:0.804461	validation_1-auc:0.802552
# [970]	validation_0-auc:0.80446	validation_1-auc:0.802552
# [971]	validation_0-auc:0.80453	validation_1-auc:0.802625
# [972]	validation_0-auc:0.8046	validation_1-auc:0.802683
# [973]	validation_0-auc:0.80473	validation_1-auc:0.80283
# [974]	validation_0-auc:0.804749	validation_1-auc:0.802849
# [975]	validation_0-auc:0.804749	validation_1-auc:0.80285
# [976]	validation_0-auc:0.804764	validation_1-auc:0.802853
# [977]	validation_0-auc:0.804764	validation_1-auc:0.802853
# [978]	validation_0-auc:0.804763	validation_1-auc:0.802853
# [979]	validation_0-auc:0.804834	validation_1-auc:0.802921
# [980]	validation_0-auc:0.804986	validation_1-auc:0.803067
# [981]	validation_0-auc:0.805043	validation_1-auc:0.803119
# [982]	validation_0-auc:0.805042	validation_1-auc:0.803118
# [983]	validation_0-auc:0.805041	validation_1-auc:0.803118
# [984]	validation_0-auc:0.805067	validation_1-auc:0.803141
# [985]	validation_0-auc:0.805082	validation_1-auc:0.80316
# [986]	validation_0-auc:0.805196	validation_1-auc:0.803276
# [987]	validation_0-auc:0.805248	validation_1-auc:0.803328
# [988]	validation_0-auc:0.805335	validation_1-auc:0.803388
# [989]	validation_0-auc:0.805369	validation_1-auc:0.803428
# [990]	validation_0-auc:0.805442	validation_1-auc:0.803509
# [991]	validation_0-auc:0.805453	validation_1-auc:0.803525
# [992]	validation_0-auc:0.805511	validation_1-auc:0.803601
# [993]	validation_0-auc:0.805616	validation_1-auc:0.803671
# [994]	validation_0-auc:0.805651	validation_1-auc:0.803702
# [995]	validation_0-auc:0.805667	validation_1-auc:0.80372
# [996]	validation_0-auc:0.805731	validation_1-auc:0.80379
# [997]	validation_0-auc:0.805756	validation_1-auc:0.803806
# [998]	validation_0-auc:0.805781	validation_1-auc:0.803839
# [999]	validation_0-auc:0.805796	validation_1-auc:0.803861
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
from sklearn.metrics import roc_auc_score
X_test_processed = processor.transform(X_test)
class_index = 1
y_pred_proba = model.predict_proba(X_test_processed)[:, class_index]
print(f'Test ROC AUC for class {class_index}:')
print(roc_auc_score(y_test, y_pred_proba))
# Out:
# Test ROC AUC for class 1:
# 0.8031107505995493

# %%
df_with_pred = pd.DataFrame({
    'id': test_id, 
    'pred_proba': y_pred_proba, 
    'decision': y_test
})

df_with_pred = df_with_pred.merge(
     test[['comment', 'major', 'gre_quant', 'degree', 'season', 'decision',
       'gre_verbal', 'date_of_result', 'term_year', 'undergrad_gpa',
       'date_added', 'applicant_status', 'university', 'gre_awa']], 
     how='left'
)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-29-39bbf376cbfa> in <module>
#       9        'gre_verbal', 'date_of_result', 'term_year', 'undergrad_gpa',
#      10        'date_added', 'applicant_status', 'university', 'gre_awa']],
# ---> 11      how='left'
#      12 )
#
# ~\Anaconda3\envs\unit2\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# ~\Anaconda3\envs\unit2\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      81         validate=validate,
#      82     )
# ---> 83     return op.get_result()
#      84
#      85
#
# ~\Anaconda3\envs\unit2\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     640             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     641
# --> 642         join_index, left_indexer, right_indexer = self._get_join_info()
#     643
#     644         ldata, rdata = self.left._data, self.right._data
#
# ~\Anaconda3\envs\unit2\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     857             )
#     858         else:
# --> 859             (left_indexer, right_indexer) = self._get_join_indexers()
#     860
#     861             if self.right_index:
#
# ~\Anaconda3\envs\unit2\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     836         """ return the join indexers """
#     837         return _get_join_indexers(
# --> 838             self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     839         )
#     840
#
# ~\Anaconda3\envs\unit2\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1318     join_func = _join_functions[how]
#    1319
# -> 1320     return join_func(lkey, rkey, count, **kwargs)
#    1321
#    1322
#
# pandas\_libs\join.pyx in pandas._libs.join.left_outer_join()
#
# MemoryError:
