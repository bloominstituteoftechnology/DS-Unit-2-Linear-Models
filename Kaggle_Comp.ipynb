# %% [markdown]
# <a href="https://colab.research.google.com/github/rubyclaguna/DS-Unit-2-Regression-Classification/blob/master/Kaggle_Comp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Data 
trainf_url = 'https://raw.githubusercontent.com/Nolanole/Tanzania-Well-Water-Project/master/train_features.csv'
testf_url = 'https://raw.githubusercontent.com/Nolanole/Tanzania-Well-Water-Project/master/test_features.csv'
trainl_url = 'https://raw.githubusercontent.com/Nolanole/Tanzania-Well-Water-Project/master/train_labels.csv'
ss_url = 'https://raw.githubusercontent.com/Nolanole/Tanzania-Well-Water-Project/master/sample_submission.csv'

# %%
X_train = pd.read_csv(trainf_url)
X_test = pd.read_csv(testf_url)
y_train = pd.read_csv(trainl_url)
sample_submission = pd.read_csv(ss_url)

# %%
X_train.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# ...

# %%
X_test.head()
# Out:
#       id  amount_tsh date_recorded                  funder  gps_height  \
# 0  50785         0.0    2013-02-04                    Dmdd        1996
# 1  51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2  17168         0.0    2013-02-01                     NaN        1567
# 3  45559         0.0    2013-01-22              Finn Water         267
# 4  49871       500.0    2013-03-27                  Bruder        1260
#
#     installer  longitude   latitude                 wpt_name  num_private  \
# 0        DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 1         DWE  36.656709  -3.309214                  Kimnyak            0
# 2         NaN  34.767863  -5.004344           Puma Secondary            0
# 3  FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 4      BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
#
#                      basin  subvillage   region  region_code  district_code  \
# ...

# %%
y_train.head()
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %%
# Drop 'id' feature for y_train, only need the status group column 
y_train = y_train.drop(columns='id')

# %%
y_train.head()
# Out:
#      status_group
# 0      functional
# 1      functional
# 2      functional
# 3  non functional
# 4      functional

# %%
print(X_train.shape)
print(y_train.shape) 
print(X_test.shape)
# Out:
# (59400, 40)
# (59400, 1)
# (14358, 40)

# %%
# Split the data 
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, random_state=42, test_size=.2)

# %%
# Try test on majority class - functional status_group 
y_pred = ['functional'] * len(X_test)
y_pred = pd.DataFrame(data = y_pred, 
                      index = X_test.index.values,
                      columns = ['status_group'])
y_pred.head()
# Out:
#       status_group
# 2980    functional
# 5246    functional
# 22659   functional
# 39888   functional
# 13361   functional

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.5435185185185185

# %%
# First Accuracy Score is 54%.

# %%
encoder = ce.OrdinalEncoder()

X_train = encoder.fit_transform(X_train)

# %%
# SUBMISSION 1 #

submission = sample_submission.copy()
submission['status_group'] = y_pred
submission.to_csv('Baseline_2_F-submission.csv', index=False)
