# %% [markdown]
# <a href="https://colab.research.google.com/github/jiobu1/DS-Unit-2-Linear-Models/blob/master/Jisha_Obukwelu_DSPT3_213_Regression_Classification_3_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 1, Module 3*
#
# ---

# %% [markdown]
# # Ridge Regression
#
# ## Assignment
#
# We're going back to our other **New York City** real estate dataset. Instead of predicting apartment rents, you'll predict property sales prices.
#
# But not just for condos in Tribeca...
#
# Instead, predict property sales prices for **One Family Dwellings** (`BUILDING_CLASS_CATEGORY` == `'01 ONE FAMILY DWELLINGS'`).
#
# Use a subset of the data where the **sale price was more than \\$100 thousand and less than $2 million.**
#
# The [NYC Department of Finance](https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page) has a glossary of property sales terms and NYC Building Class Code Descriptions. The data comes from the [NYC OpenData](https://data.cityofnewyork.us/browse?q=NYC%20calendar%20sales) portal.
#
# - [x] Do train/test split. Use data from January — March 2019 to train. Use data from April 2019 to test.
# - [x] Do one-hot encoding of categorical features.
# - [x] Do feature selection with `SelectKBest`.
# - [x] Do [feature scaling](https://scikit-learn.org/stable/modules/preprocessing.html).
# - [x] Fit a ridge regression model with multiple features.
# - [x] Get mean absolute error for the test set.
# - [x] As always, commit your notebook to your fork of the GitHub repo.
#
#
# ## Stretch Goals
# - [x] Add your own stretch goal(s) !
# - [x] Instead of `Ridge`, try `LinearRegression`. Depending on how many features you select, your errors will probably blow up! 💥
# - [ ] Instead of `Ridge`, try [`RidgeCV`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.RidgeCV.html).
# - [ ] Learn more about feature selection:
#     - ["Permutation importance"](https://www.kaggle.com/dansbecker/permutation-importance)
#     - [scikit-learn's User Guide for Feature Selection](https://scikit-learn.org/stable/modules/feature_selection.html)
#     - [mlxtend](http://rasbt.github.io/mlxtend/) library
#     - scikit-learn-contrib libraries: [boruta_py](https://github.com/scikit-learn-contrib/boruta_py) & [stability-selection](https://github.com/scikit-learn-contrib/stability-selection)
#     - [_Feature Engineering and Selection_](http://www.feat.engineering/) by Kuhn & Johnson.
# - [ ] Try [statsmodels](https://www.statsmodels.org/stable/index.html) if you’re interested in more inferential statistical approach to linear regression and feature selection, looking at p values and 95% confidence intervals for the coefficients.
# - [ ] Read [_An Introduction to Statistical Learning_](http://faculty.marshall.usc.edu/gareth-james/ISL/ISLR%20Seventh%20Printing.pdf), Chapters 1-3, for more math & theory, but in an accessible, readable way.
# - [ ] Try [scikit-learn pipelines](https://scikit-learn.org/stable/modules/compose.html).

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Applied-Modeling/master/data/'
    # !pip install category_encoders==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'
    
# Ignore this Numpy warning when using Plotly Express:
# FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning, module='numpy')

# %%
import pandas as pd
import pandas_profiling

# Read New York City property sales data
df = pd.read_csv(DATA_PATH+'condos/NYC_Citywide_Rolling_Calendar_Sales.csv')

# Change column names: replace spaces with underscores
df.columns = [col.replace(' ', '_') for col in df]

# SALE_PRICE was read as strings.
# Remove symbols, convert to integer
df['SALE_PRICE'] = (
    df['SALE_PRICE']
    .str.replace('$','')
    .str.replace('-','')
    .str.replace(',','')
    .astype(int)
)

# %%
# BOROUGH is a numeric column, but arguably should be a categorical feature,
# so convert it from a number to a string
df['BOROUGH'] = df['BOROUGH'].astype(str)

# %%
# Reduce cardinality for NEIGHBORHOOD feature

# Get a list of the top 10 neighborhoods
top10 = df['NEIGHBORHOOD'].value_counts()[:10].index
print(top10)

# At locations where the neighborhood is NOT in the top 10, 
# replace the neighborhood with 'OTHER'
df.loc[~df['NEIGHBORHOOD'].isin(top10), 'NEIGHBORHOOD'] = 'OTHER'
# Out:
# Index(['FLUSHING-NORTH', 'UPPER EAST SIDE (59-79)', 'UPPER EAST SIDE (79-96)',
#        'BEDFORD STUYVESANT', 'BOROUGH PARK', 'UPPER WEST SIDE (59-79)',
#        'GRAMERCY', 'ASTORIA', 'FOREST HILLS', 'UPPER WEST SIDE (79-96)'],
#       dtype='object')

# %% [markdown]
# #### Taking care of imports

# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import category_encoders as ce

from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %matplotlib inline
from IPython.display import display, HTML
from ipywidgets import interact
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #####Data Exploration

# %%
df.head()
# Out:
#   BOROUGH             NEIGHBORHOOD  ... SALE_PRICE   SALE_DATE
# 0       1                    OTHER  ...          0  01/01/2019
# 1       1                    OTHER  ...          0  01/01/2019
# 2       1                    OTHER  ...          0  01/01/2019
# 3       1                    OTHER  ...          0  01/01/2019
# 4       1  UPPER EAST SIDE (59-79)  ...          0  01/01/2019
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING_CLASS_CATEGORY               0
# TAX_CLASS_AT_PRESENT                  1
# BLOCK                                 0
# LOT                                   0
# EASE-MENT                         23040
# BUILDING_CLASS_AT_PRESENT             1
# ADDRESS                               0
# APARTMENT_NUMBER                  17839
# ZIP_CODE                              1
# RESIDENTIAL_UNITS                     1
# COMMERCIAL_UNITS                      1
# TOTAL_UNITS                           1
# LAND_SQUARE_FEET                     53
# GROSS_SQUARE_FEET                     1
# YEAR_BUILT                           35
# TAX_CLASS_AT_TIME_OF_SALE             0
# BUILDING_CLASS_AT_TIME_OF_SALE        0
# SALE_PRICE                            0
# SALE_DATE                             0
# dtype: int64

# %% [markdown]
# ##### Dropping EASE-MENT and APARTMENT_NUMBER

# %%
df = df.drop(columns=['EASE-MENT', 'APARTMENT_NUMBER'], axis=1)
print(df.shape)
df.columns
# Out:
# (23040, 19)
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING_CLASS_CATEGORY',
#        'TAX_CLASS_AT_PRESENT', 'BLOCK', 'LOT', 'BUILDING_CLASS_AT_PRESENT',
#        'ADDRESS', 'ZIP_CODE', 'RESIDENTIAL_UNITS', 'COMMERCIAL_UNITS',
#        'TOTAL_UNITS', 'LAND_SQUARE_FEET', 'GROSS_SQUARE_FEET', 'YEAR_BUILT',
#        'TAX_CLASS_AT_TIME_OF_SALE', 'BUILDING_CLASS_AT_TIME_OF_SALE',
#        'SALE_PRICE', 'SALE_DATE'],
#       dtype='object')

# %% [markdown]
# #### 1. Predict property sales prices for One Family Dwellings (BUILDING_CLASS_CATEGORY == '01 ONE FAMILY DWELLINGS').

# %% [markdown]
# ##### Checking Building Class

# %%
df.BUILDING_CLASS_CATEGORY.value_counts()
# Out:
# 01 ONE FAMILY DWELLINGS                       5061
# 02 TWO FAMILY DWELLINGS                       4567
# 10 COOPS - ELEVATOR APARTMENTS                3471
# 13 CONDOS - ELEVATOR APARTMENTS               3339
# 03 THREE FAMILY DWELLINGS                     1438
# 07 RENTALS - WALKUP APARTMENTS                 807
# 09 COOPS - WALKUP APARTMENTS                   672
# 15 CONDOS - 2-10 UNIT RESIDENTIAL              421
# 04 TAX CLASS 1 CONDOS                          418
# 44 CONDO PARKING                               366
# 17 CONDO COOPS                                 300
# 22 STORE BUILDINGS                             288
# 05 TAX CLASS 1 VACANT LAND                     288
# 12 CONDOS - WALKUP APARTMENTS                  256
# 14 RENTALS - 4-10 UNIT                         200
# 29 COMMERCIAL GARAGES                          147
# 08 RENTALS - ELEVATOR APARTMENTS               120
# 30 WAREHOUSES                                  105
# 21 OFFICE BUILDINGS                             96
# 43 CONDO OFFICE BUILDINGS                       80
# 31 COMMERCIAL VACANT LAND                       80
# 47 CONDO NON-BUSINESS STORAGE                   75
# 46 CONDO STORE BUILDINGS                        65
# 27 FACTORIES                                    54
# 06 TAX CLASS 1 - OTHER                          42
# 37 RELIGIOUS FACILITIES                         38
# 45 CONDO HOTELS                                 32
# 41 TAX CLASS 4 - OTHER                          30
# 11A CONDO-RENTALS                               30
# 16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT      29
# 33 EDUCATIONAL FACILITIES                       24
# 28 COMMERCIAL CONDOS                            23
# 32 HOSPITAL AND HEALTH FACILITIES               21
# 26 OTHER HOTELS                                 15
# 34 THEATRES                                      7
# 35 INDOOR PUBLIC AND CULTURAL FACILITIES         7
# 23 LOFT BUILDINGS                                7
# 25 LUXURY HOTELS                                 6
# 36 OUTDOOR RECREATIONAL FACILITIES               4
# 49 CONDO WAREHOUSES/FACTORY/INDUS                4
# 48 CONDO TERRACES/GARDENS/CABANAS                3
# 38 ASYLUMS AND HOMES                             2
# 42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC        1
# 39 TRANSPORTATION FACILITIES                     1
# Name: BUILDING_CLASS_CATEGORY, dtype: int64

# %%
#BUILDING_CLASS_CATEGORY == '01 ONE FAMILY DWELLINGS'
df_1 = df[df['BUILDING_CLASS_CATEGORY']== '01 ONE FAMILY DWELLINGS']

# %%
df_1.head()
# Out:
#    BOROUGH NEIGHBORHOOD  ... SALE_PRICE   SALE_DATE
# 7        2        OTHER  ...          0  01/01/2019
# 8        2        OTHER  ...          0  01/01/2019
# 9        2        OTHER  ...          0  01/01/2019
# 42       3        OTHER  ...          0  01/01/2019
# 44       3        OTHER  ...     550000  01/01/2019
#
# [5 rows x 19 columns]

# %%
df_1.shape
# Out:
# (5061, 19)

# %% [markdown]
# ##### Changing 'LAND_SQUARE_FEET' to an int

# %%
df_1['LAND_SQUARE_FEET'] = (
    df_1['LAND_SQUARE_FEET']
    .str.replace(',','')
    .astype(int)
)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# #### 2. Use a subset of the data where the sale price was more than 100 thousand and less than $2 million.

# %%
df_1 = df_1[df_1['SALE_PRICE'] < 2000000]
df_1 = df_1[df_1['SALE_PRICE'] > 100000]

# %% [markdown]
# ##### Checking SALE_PRICE is within the appropriate range

# %%
print(min(df_1['SALE_PRICE']), max(df_1['SALE_PRICE']))
# Out:
# 104000 1955000

# %% [markdown]
# #### 3. Do train/test split. Use data from January — March 2019 to train. Use data from April 2019 to test.

# %% [markdown]
# ##### Changing created by column into date time format

# %%
df_1['SALE_DATE'] = pd.to_datetime(df_1['SALE_DATE'], infer_datetime_format = True)

# %%
train = df_1[df_1['SALE_DATE'] < '04-01-2019']
test = df_1[df_1['SALE_DATE'] >= '04-01-2019']

# %% [markdown]
# ##### Checking that the test and train dataframes have the appropriate months

# %%
min(train['SALE_DATE']), max(train['SALE_DATE']), min(test['SALE_DATE']), max(test['SALE_DATE'])
# Out:
# (Timestamp('2019-01-01 00:00:00'),
#  Timestamp('2019-03-30 00:00:00'),
#  Timestamp('2019-04-01 00:00:00'),
#  Timestamp('2019-04-30 00:00:00'))

# %% [markdown]
# ##### Checking train/test shape

# %%
print(train.shape, test.shape)
# Out:
# (2507, 19) (644, 19)

# %% [markdown]
# ####4. Do one-hot encoding of categorical features.

# %% [markdown]
# ##### Checking relationships among the featres.

# %%
train.corr()
# Out:
#                               BLOCK  ...  SALE_PRICE
# BLOCK                      1.000000  ...   -0.147684
# LOT                        0.048937  ...   -0.047241
# ZIP_CODE                   0.644818  ...    0.205550
# RESIDENTIAL_UNITS         -0.171459  ...    0.087763
# COMMERCIAL_UNITS          -0.027522  ...    0.123074
# TOTAL_UNITS               -0.131137  ...    0.149575
# LAND_SQUARE_FEET          -0.042277  ...    0.278144
# GROSS_SQUARE_FEET         -0.134267  ...    0.454418
# YEAR_BUILT                -0.189535  ...   -0.037376
# TAX_CLASS_AT_TIME_OF_SALE       NaN  ...         NaN
# SALE_PRICE                -0.147684  ...    1.000000
#
# [11 rows x 11 columns]

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data = train.corr(), annot=True)

#https://github.com/mwaskom/seaborn/issues/1773
# fix for mpl bug that cuts off top/bottom of seaborn viz
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show()

# %%
train.select_dtypes(include = 'number').describe().T
# Out:
#                             count           mean  ...       75%        max
# BLOCK                      2507.0    6758.303949  ...    9888.5    16350.0
# LOT                        2507.0      75.778221  ...      70.0     2720.0
# ZIP_CODE                   2507.0   10993.398484  ...   11413.0    11697.0
# RESIDENTIAL_UNITS          2507.0       0.987635  ...       1.0        1.0
# COMMERCIAL_UNITS           2507.0       0.016354  ...       0.0        2.0
# TOTAL_UNITS                2507.0       1.003989  ...       1.0        3.0
# LAND_SQUARE_FEET           2507.0    3146.051057  ...    4000.0    18906.0
# GROSS_SQUARE_FEET          2507.0    1473.744715  ...    1683.0     7875.0
# YEAR_BUILT                 2507.0    1944.766653  ...    1960.0     2018.0
# TAX_CLASS_AT_TIME_OF_SALE  2507.0       1.000000  ...       1.0        1.0
# SALE_PRICE                 2507.0  621573.742321  ...  750000.0  1955000.0
#
# [11 rows x 8 columns]

# %%
sns.set()

number = train.select_dtypes('number')

for col in number.columns:
  
  sns.lmplot(x=col, y='SALE_PRICE', data=train, scatter_kws=dict(alpha=0.5))
  plt.show()

# %%
train.select_dtypes(exclude = 'number').describe().T
# Out:
#                                count unique  ...      first       last
# BOROUGH                         2507      5  ...        NaT        NaT
# NEIGHBORHOOD                    2507      6  ...        NaT        NaT
# BUILDING_CLASS_CATEGORY         2507      1  ...        NaT        NaT
# TAX_CLASS_AT_PRESENT            2507      2  ...        NaT        NaT
# BUILDING_CLASS_AT_PRESENT       2507     13  ...        NaT        NaT
# ADDRESS                         2507   2497  ...        NaT        NaT
# BUILDING_CLASS_AT_TIME_OF_SALE  2507     11  ...        NaT        NaT
# SALE_DATE                       2507     68  ... 2019-01-01 2019-03-30
#
# [8 rows x 6 columns]

# %% [markdown]
# ##### Checking non-numeric columns relationship to price

# %%
train.groupby('BOROUGH')['SALE_PRICE'].mean()
# Out:
# BOROUGH
# 1    739000.000000
# 2    473104.623967
# 3    768734.633166
# 4    649005.172757
# 5    537305.802115
# Name: SALE_PRICE, dtype: float64

# %%
import plotly.express as px

# %%
sns.scatterplot(x = 'BOROUGH', y = 'SALE_PRICE', data = train)

# %% [markdown]
# The relationship between price and borough is very interesting. You can see while most boroughs have some 1 family homes between $100,000 to $1million. Boroughs 3 and 4 seems to have the more listings that are greater than $1 million.

# %%
train.groupby('NEIGHBORHOOD')['SALE_PRICE'].mean()
# Out:
# NEIGHBORHOOD
# ASTORIA               1.001955e+06
# BEDFORD STUYVESANT    6.215972e+05
# BOROUGH PARK          1.008917e+06
# FLUSHING-NORTH        8.689417e+05
# FOREST HILLS          1.210753e+06
# OTHER                 6.056645e+05
# Name: SALE_PRICE, dtype: float64

# %%
plt.figure(figsize = (12,10))
sns.scatterplot(x = 'NEIGHBORHOOD', y = 'SALE_PRICE', data = train)

# %%
train.groupby('TAX_CLASS_AT_PRESENT')['SALE_PRICE'].mean()
# Out:
# TAX_CLASS_AT_PRESENT
# 1     624436.781906
# 1D    392900.000000
# Name: SALE_PRICE, dtype: float64

# %%
sns.scatterplot(x = 'TAX_CLASS_AT_PRESENT', y = 'SALE_PRICE', data = train)

# %% [markdown]
# ##### It seems as if most of the higher priced properties are in the TAX_CLASS 1.

# %% [markdown]
# ##### Dropping columns and price

# %%
target = 'SALE_PRICE'
high_cardinality = ['ADDRESS','SALE_DATE']
features = train.columns.drop([target] + high_cardinality)

X_train = train[features]
y_train = train[target]
X_test = test[features]
y_test = test[target]

# %% [markdown]
# #####Checking X_train before encoding:

# %%
print(X_train.shape)
X_train.head()
# Out:
# (2507, 16)
#     BOROUGH  ... BUILDING_CLASS_AT_TIME_OF_SALE
# 44        3  ...                             A9
# 61        4  ...                             A1
# 78        2  ...                             A1
# 108       3  ...                             A1
# 111       3  ...                             A5
#
# [5 rows x 16 columns]

# %% [markdown]
# ##### OneHotEncoder

# %%
encoder = ce.OneHotEncoder(use_cat_names = True)

#One-hot encoding
X_train = encoder.fit_transform(X_train)
X_test = encoder.transform(X_test)

#Scaling data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
print(X_train.shape)
X_train.head()
# Out:
# (2507, 48)
#      BOROUGH_3  ...  BUILDING_CLASS_AT_TIME_OF_SALE_S0
# 44           1  ...                                  0
# 61           0  ...                                  0
# 78           0  ...                                  0
# 108          1  ...                                  0
# 111          1  ...                                  0
#
# [5 rows x 48 columns]

# %% [markdown]
# #### 4. Do feature selection with `SelectKBest`.
#
# #### 5. Do feature scaling
#
# #### 6. Get MAE for the test set

# %% [markdown]
# #####Using loop to see what is the best features to select

# %%
best_mae = []
mse = []
rmse = []
r2 = []
intercept = []

# %%
# Loop for selecting feature and getting linear regression data

for k in range(1, len(X_train.columns)+1):
  print(f'{k} features:')

  # SelectKBest
  selector = SelectKBest(score_func=f_regression, k=k)

  # Feature scaling 
  X_train_selected = selector.fit_transform(X_train_scaled, y_train)
  X_test_selected = selector.transform(X_test_scaled)

  print(X_train.columns[:k])

  # Create linear regression model
  model = LinearRegression()
  model.fit(X_train_selected, y_train)

  # Predict y for X test data
  y_pred = model.predict(X_test_selected)

  # Mean Absolute Error
  mae = mean_absolute_error(y_test, y_pred)
  print(f'TEST MAE: ${mae:,.0f}\n')
  

  #Test
  test_mse = mean_squared_error(y_test, y_pred)
  test_rmse = np.sqrt(test_mse)
  test_r2 = r2_score(y_test, y_pred)

  #Taking care of all my prints
  #Testing Data
  print('Test Data:')
  print(f'Test MSE: ${test_mse:.2f}')
  print(f'Test RMSE: ${test_rmse:.2f}')
  print(f'Test R^2: {test_r2:.2f} \n')

  #Model Interecept and Coefficients
  print('Model Intercept and Coefficients \n')
  print(f'Model intercept {model.intercept_} \n')
  print(f'Coefficients \n{(model.coef_)}')

  #Adding data to arrays
  best_mae.append(mae)
  mse.append(test_mse)
  rmse.append(test_rmse)
  r2.append(test_r2)
  intercept.append(model.intercept_)
# Out:
# 1 features:
# Index(['BOROUGH_3'], dtype='object')
# TEST MAE: $183,641
#
# Test Data:
# Test MSE: $69121062299.79
# Test RMSE: $262908.85
# Test R^2: 0.22
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [132485.2427969]
# 2 features:
# Index(['BOROUGH_3', 'BOROUGH_4'], dtype='object')
# TEST MAE: $179,555
#
# Test Data:
# Test MSE: $67105172349.92
# Test RMSE: $259046.66
# Test R^2: 0.24
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [ 34871.94387874 118933.0648235 ]
# 3 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2'], dtype='object')
# TEST MAE: $179,291
#
# Test Data:
# Test MSE: $66843669646.28
# Test RMSE: $258541.43
# Test R^2: 0.24
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [ 31358.28044211 112455.59382332  21227.09477426]
# 4 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5'], dtype='object')
# TEST MAE: $179,365
#
# Test Data:
# Test MSE: $66896544174.06
# Test RMSE: $258643.66
# Test R^2: 0.24
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [-2.29221233e+17  3.14880000e+04  1.12400000e+05  2.29221233e+17]
# 5 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1'], dtype='object')
# TEST MAE: $170,946
#
# Test Data:
# Test MSE: $62444267321.43
# Test RMSE: $249888.51
# Test R^2: 0.29
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [-6.50790518e+04  1.60297163e+18  3.40800000e+04  1.10144000e+05
#  -1.60297163e+18]
# 6 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER'],
#       dtype='object')
# TEST MAE: $169,924
#
# Test Data:
# Test MSE: $57691431920.60
# Test RMSE: $240190.41
# Test R^2: 0.34
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [ 7.19923624e+04 -6.51123889e+04 -4.13880375e+17  5.30417385e+04
#   9.97284931e+04  4.13880375e+17]
# 7 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH'],
#       dtype='object')
# TEST MAE: $168,126
#
# Test Data:
# Test MSE: $56357963780.98
# Test RMSE: $237398.32
# Test R^2: 0.36
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [ 6.16737649e+04 -5.67256453e+04 -5.97817603e+17  5.47689337e+04
#   5.57723181e+04  1.02805237e+05  5.97817603e+17]
# 8 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT'],
#       dtype='object')
# TEST MAE: $168,873
#
# Test Data:
# Test MSE: $57128752679.94
# Test RMSE: $239016.22
# Test R^2: 0.35
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [ 6.18380718e+04  6.63693904e+03 -5.82735298e+04  4.81024923e+18
#   5.79649568e+04  5.51233771e+04  1.03295630e+05 -4.81024923e+18]
# 9 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS'],
#       dtype='object')
# TEST MAE: $167,957
#
# Test Data:
# Test MSE: $55975015721.65
# Test RMSE: $236590.40
# Test R^2: 0.36
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [ 6.27485232e+04  3.56281548e+03 -4.83145930e+04  2.27615178e+04
#   1.38218853e+18  5.67378754e+04  5.68469391e+04  1.03470543e+05
#  -1.38218853e+18]
# 10 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK'],
#       dtype='object')
# TEST MAE: $165,328
#
# Test Data:
# Test MSE: $53597179838.37
# Test RMSE: $231510.65
# Test R^2: 0.39
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214996
#
# Coefficients
# [ 2.03618501e+04 -1.70816993e+05 -2.89776944e+05 -2.94637850e+04
#   3.18813876e+04 -2.51804253e+18 -2.37099376e+05  4.92606770e+04
#   1.02948546e+05  2.51804253e+18]
# 11 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA'],
#       dtype='object')
# TEST MAE: $165,323
#
# Test Data:
# Test MSE: $53984643718.52
# Test RMSE: $232345.96
# Test R^2: 0.39
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214996
#
# Coefficients
# [ 2.11051533e+04 -1.79538096e+05 -2.90175546e+05 -2.68816009e+04
#   1.41767458e+04  2.81611663e+04 -1.97477369e+17 -2.40766367e+05
#   5.15701036e+04  1.02648245e+05  1.97477369e+17]
# 12 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS'],
#       dtype='object')
# TEST MAE: $164,727
#
# Test Data:
# Test MSE: $53754505487.96
# Test RMSE: $231850.18
# Test R^2: 0.39
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214996
#
# Coefficients
# [ 1.98894136e+04 -1.85935840e+05 -3.00774164e+05 -2.77801914e+04
#   1.32706266e+04  2.69169084e+04 -7.67805908e+17 -2.51472536e+05
#  -8.45816452e+03  5.15141929e+04  1.05503356e+05  7.67805908e+17]
# 13 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1'],
#       dtype='object')
# TEST MAE: $155,433
#
# Test Data:
# Test MSE: $50925965562.01
# Test RMSE: $225667.82
# Test R^2: 0.42
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214999
#
# Coefficients
# [ 1.94178488e+04 -1.04938348e+05 -1.60125008e+05 -4.58719265e+03
#   2.24177250e+04  2.55345495e+04 -9.66442275e+04  1.80053038e+19
#  -4.25942438e+04 -9.32938446e+03  5.87041145e+04  9.96154733e+04
#  -1.80053038e+19]
# 14 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D'],
#       dtype='object')
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
# TEST MAE: $156,207
#
# Test Data:
# Test MSE: $50971664108.22
# Test RMSE: $225769.05
# Test R^2: 0.42
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214997
#
# Coefficients
# [ 1.62099603e+04 -1.37153217e+05 -2.15236968e+05 -9.65125824e+03
#   1.39100488e+04  2.53837798e+04 -9.00972048e+04  7.83190613e+18
#  -1.04040170e+05  5.49301714e+04 -5.68240925e+04  6.21310804e+04
#   1.04212282e+05 -7.83190613e+18]
# 15 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK'],
#       dtype='object')
# TEST MAE: $156,693
#
# Test Data:
# Test MSE: $51159507487.80
# Test RMSE: $226184.68
# Test R^2: 0.42
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214997
#
# Coefficients
# [ 1.91981235e+04 -1.32794444e+05 -2.07942550e+05 -9.71101625e+03
#   1.41946810e+04  2.52764350e+04 -9.30375279e+04 -2.40676565e+02
#  -1.19055825e+18 -9.48391079e+04  5.71112873e+04 -5.97007817e+04
#   6.35476246e+04  1.03206799e+05  1.19055825e+18]
# 16 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT'],
#       dtype='object')
# TEST MAE: $156,468
#
# Test Data:
# Test MSE: $51028450402.16
# Test RMSE: $225894.78
# Test R^2: 0.42
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214997
#
# Coefficients
# [ 1.94044320e+04 -1.31772256e+05 -2.06531398e+05 -1.09134871e+04
#   1.44296787e+04  2.44505386e+04 -9.19392601e+04  1.14181468e+04
#   4.03600045e+18 -9.35194335e+04  5.49491271e+04 -5.76432497e+04
#   6.25861074e+04  1.03029038e+05 -1.21609979e+04 -4.03600045e+18]
# 17 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9'],
#       dtype='object')
# TEST MAE: $156,356
#
# Test Data:
# Test MSE: $50919121771.17
# Test RMSE: $225652.66
# Test R^2: 0.42
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214997
#
# Coefficients
# [ 1.81899100e+04 -1.32829148e+05 -2.07472741e+05 -1.20084630e+04
#   1.25387035e+04  2.53512877e+04 -9.19195123e+04  1.02838327e+04
#  -2.77848846e+18 -9.56680752e+04  1.06842012e+05 -5.67670669e+04
#   6.01995492e+04  1.04230153e+05 -1.25145033e+04  2.77848846e+18
#  -5.54211086e+04]
# 18 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1'],
#       dtype='object')
# TEST MAE: $156,056
#
# Test Data:
# Test MSE: $50713773611.98
# Test RMSE: $225197.19
# Test R^2: 0.42
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214997
#
# Coefficients
# [ 1.67933452e+04 -1.32832867e+05 -2.08435323e+05 -1.90838448e+04
#   2.86624941e+03  1.59634235e+04 -9.28239187e+04  1.08396308e+04
#  -2.69109208e+18 -4.37700756e+18 -9.48604823e+04  1.07046039e+05
#  -5.73391842e+04  6.08993462e+04  1.03509755e+05 -1.19401784e+04
#   2.69109208e+18  4.37700756e+18]
# 19 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5'],
#       dtype='object')
# TEST MAE: $156,687
#
# Test Data:
# Test MSE: $51221320849.54
# Test RMSE: $226321.28
# Test R^2: 0.42
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214997
#
# Coefficients
# [ 1.92213930e+04 -1.29030432e+05 -2.03899945e+05 -1.69252727e+03
#   2.14250491e+04  2.37255167e+04 -9.27850457e+04  1.14388962e+04
#   7.98547597e+18  1.27970374e+18 -9.02915538e+04  1.06907489e+05
#  -5.64764552e+04  5.99076499e+04  1.02951161e+05 -1.24680078e+04
#  -7.98547597e+18 -1.27970374e+18 -5.46790452e+03]
# 20 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0'],
#       dtype='object')
# TEST MAE: $156,394
#
# Test Data:
# Test MSE: $50889977698.55
# Test RMSE: $225588.07
# Test R^2: 0.42
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214997
#
# Coefficients
# [ 2.07805769e+04 -1.34807846e+05 -2.07791594e+05 -1.50023574e+04
#   1.31746027e+04  1.97470151e+04 -9.08386894e+04  6.83561701e+03
#   4.88344548e+18 -7.73195929e+18  1.65771165e+15 -9.73932585e+04
#   1.00207207e+05 -5.43056134e+04  5.99076866e+04  1.01372406e+05
#  -1.17461366e+04 -4.88344548e+18  7.73195929e+18 -1.65771165e+15]
# 21 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2'],
#       dtype='object')
# TEST MAE: $153,959
#
# Test Data:
# Test MSE: $49418486640.68
# Test RMSE: $222302.69
# Test R^2: 0.44
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214997
#
# Coefficients
# [ 1.34739541e+04 -1.39806627e+05 -2.17651421e+05  1.25202209e+04
#   3.24186320e+04  2.75293128e+04  2.20414436e+04 -9.44856931e+04
#   1.14729384e+04 -2.62078326e+18 -3.54791554e+18 -2.12485633e+18
#  -1.03079494e+05  1.05768057e+05 -5.67355868e+04  6.11394347e+04
#   1.03784117e+05 -1.37834030e+04  2.62078326e+18  3.54791554e+18
#   2.12485633e+18]
# 22 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3'],
#       dtype='object')
# TEST MAE: $154,483
#
# Test Data:
# Test MSE: $49653184125.46
# Test RMSE: $222829.94
# Test R^2: 0.44
#
# Model Intercept and Coefficients
#
# Model intercept 621573.7423214997
#
# Coefficients
# [ 8.72523777e+04  1.00014637e+05 -8.52761868e+04 -1.38453042e+05
#   1.53667710e+04  3.39147207e+04  3.47446052e+04  2.01536464e+04
#  -9.33322773e+04  1.12601237e+04  1.34976256e+17  6.27036747e+17
#  -1.62000519e+16 -1.14621631e+05  1.07891042e+05 -5.83189224e+04
#   5.96518457e+04  1.04410705e+05 -1.36494690e+04 -1.34976256e+17
#  -6.27036747e+17  1.62000519e+16]
# 23 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1'],
#       dtype='object')
# TEST MAE: $155,388
#
# Test Data:
# Test MSE: $49651751814.31
# Test RMSE: $222826.73
# Test R^2: 0.44
#
# Model Intercept and Coefficients
#
# Model intercept 621433.2006262484
#
# Coefficients
# [ 8.84095818e+04  9.67019581e+04 -9.17049590e+04 -1.50225847e+05
#   2.46093620e+04  3.82070449e+04  4.00634190e+04  2.44577154e+04
#  -9.78815570e+04  1.29771147e+04  8.68752666e+18  9.70787161e+18
#  -7.01650340e+16 -1.14018338e+05 -5.44170117e+18 -5.78059733e+04
#   6.16369793e+04  1.05351495e+05 -1.58799197e+04 -8.68752666e+18
#  -4.52535205e+18  7.01650340e+16  1.67246330e+18]
# 24 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4'],
#       dtype='object')
# TEST MAE: $154,885
#
# Test Data:
# Test MSE: $49803653091.77
# Test RMSE: $223167.32
# Test R^2: 0.43
#
# Model Intercept and Coefficients
#
# Model intercept 621380.2702680642
#
# Coefficients
# [ 1.14441551e+05  1.33328596e+05 -6.57735584e+04 -1.06036414e+05
#   2.99127588e+04  4.38102899e+04  4.44630717e+04  2.53076641e+04
#  -9.31651465e+04  1.01076047e+04  4.93874969e+17  3.65893683e+18
#  -1.14991254e+17  1.05769193e+18 -1.10389126e+05 -7.49113705e+18
#  -5.86335418e+04  6.01688359e+04  1.05120930e+05 -1.30262919e+04
#  -4.93874969e+17  3.47540647e+18  1.14991254e+17  1.24464908e+18]
# 25 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6'],
#       dtype='object')
# TEST MAE: $8,697,815,876,718,932
#
# Test Data:
# Test MSE: $48719888658573456567391173879005184.00
# Test RMSE: $220725822364700800.00
# Test R^2: -553256990366332537012224.00
#
# Model Intercept and Coefficients
#
# Model intercept 621184.0635484726
#
# Coefficients
# [ 1.15108665e+05  1.35272650e+05 -6.39449876e+04 -1.07971468e+05
#   2.57159456e+04  4.02617126e+04  4.34763753e+04  2.49312464e+04
#  -9.30921289e+04  1.22508982e+04  2.16942920e+17  3.77252097e+18
#  -5.15173514e+16  1.19911045e+18 -1.11833273e+05 -6.76767473e+18
#  -9.62094406e+17  5.90538481e+04  1.05403739e+05 -1.32808511e+04
#  -2.16942920e+17  3.36599860e+18  5.15173514e+16 -6.19010350e+17
#   1.10457830e+18]
# 26 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8'],
#       dtype='object')
# TEST MAE: $194,554,569,709,682
#
# Test Data:
# Test MSE: $24376353464569316299772790833152.00
# Test RMSE: $4937241483315285.00
# Test R^2: -276814835280627957760.00
#
# Model Intercept and Coefficients
#
# Model intercept 621362.9625328436
#
# Coefficients
# [ 1.21079946e+05  1.41454838e+05 -5.84174194e+04 -1.00044231e+05
#   2.83963186e+04  4.12551337e+04  3.95126858e+04  2.60647348e+04
#  -9.44545257e+04  8.95052879e+03 -2.79735447e+17  4.23324163e+18
#  -4.14723393e+16  9.96082902e+16  4.95859974e+18 -1.10801279e+05
#  -8.34739787e+18  2.15203294e+16  5.93374355e+04  1.05062681e+05
#  -1.40995119e+04  2.79735447e+17  3.70107461e+18  4.14723393e+16
#  -8.57621368e+16 -2.39809754e+18]
# 27 features:
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2'],
#       dtype='object')
# TEST MAE: $7,034,230,613,297,467
#
# Test Data:
# Test MSE: $31865377805359601128132805818056704.00
# Test RMSE: $178508761144543264.00
# Test R^2: -361859263370401870249984.00
#
# Model Intercept and Coefficients
#
# Model intercept 621623.3037636821
#
# Coefficients
# [ 1.09090313e+05  1.25778815e+05 -6.86276095e+04 -1.13574978e+05
#   2.08653164e+04  3.73142358e+04  3.93742313e+04  2.15386266e+04
#   3.47436355e+17 -9.31304850e+04  1.17388800e+04  6.05810655e+16
#   1.39160289e+18 -4.80330387e+15  4.04287146e+16  7.18023276e+17
#  -1.12136798e+05 -4.81007598e+18  7.78079695e+17  6.00005667e+04
#   1.04651283e+05 -1.38202392e+04 -6.05810655e+16  2.62877511e+18
#   4.80330387e+15  1.12750443e+17  5.79402543e+17]
# 28 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0'],
#       dtype='object')
# TEST MAE: $43,463,984,125,320,128
#
# Test Data:
# Test MSE: $1216591937925031955903218028568903680.00
# Test RMSE: $1102992265578064640.00
# Test R^2: -13815466591012025796657152.00
#
# Model Intercept and Coefficients
#
# Model intercept 622651.6290097891
#
# Coefficients
# [ 1.09461548e+05  1.23495222e+05 -7.11834504e+04 -1.17892739e+05
#   1.94015497e+04  3.75226174e+04  3.80587538e+04  2.23000377e+04
#  -6.25990546e+16 -9.35085004e+04  1.16792656e+04  2.57000475e+16
#   5.06127432e+17  1.07516978e+17  3.49423780e+18  5.25556954e+17
#  -1.13154178e+05  1.41699898e+18 -3.69409557e+18  2.60533106e+18
#   5.95484646e+04  1.04027326e+05 -1.38964745e+04 -2.57000475e+16
#   1.13490365e+18 -1.07516978e+17 -3.38372990e+17  4.02411991e+15]
# 29 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0',
#        'BUILDING_CLASS_AT_PRESENT_B3'],
#       dtype='object')
# TEST MAE: $61,609,188,188,347,688
#
# Test Data:
# Test MSE: $2444425692570099008854852448546717696.00
# Test RMSE: $1563465923060077056.00
# Test R^2: -27758593853179590017548288.00
#
# Model Intercept and Coefficients
#
# Model intercept 622761.88007352
#
# Coefficients
# [ 1.32467207e+05  1.53979032e+05 -5.15192504e+04 -8.84595069e+04
#   2.48579114e+04  4.04822050e+04  4.16085971e+04  2.44139335e+04
#  -9.54835106e+17  5.56305355e+17 -9.37966289e+04  1.09393606e+04
#   8.18355469e+15  8.86048690e+17 -4.03808636e+16  1.49182631e+17
#   2.27496081e+18 -1.08853720e+05  3.21916898e+18 -6.25150138e+18
#   1.81141692e+18  5.97335587e+04  1.04629188e+05 -1.35552608e+04
#  -8.18355469e+15  3.76259056e+18  4.03808636e+16  2.72430929e+18
#  -7.74787302e+17]
# 30 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0',
#        'BUILDING_CLASS_AT_PRESENT_B3', 'ZIP_CODE'],
#       dtype='object')
# TEST MAE: $81,123,936,680,226,512
#
# Test Data:
# Test MSE: $4238223957992118351961953239721574400.00
# Test RMSE: $2058694721903205888.00
# Test R^2: -48128743641629311891406848.00
#
# Model Intercept and Coefficients
#
# Model intercept 623585.2278665991
#
# Coefficients
# [ 7.46540269e+04  6.93768473e+04 -9.32786494e+04 -1.50661132e+05
#   8.18492921e+04  8.61948266e+04  6.14450492e+04  4.19113481e+04
#   3.37684401e+04 -7.71532634e+17  7.86021283e+17 -9.39893229e+04
#   9.33639348e+03  1.75947295e+18 -1.52086007e+18 -1.29310444e+17
#   6.67588621e+17  2.68515229e+18 -9.69160956e+04  5.50098243e+18
#  -2.20322912e+18  4.23508696e+17  5.99351464e+04  1.05641145e+05
#  -1.14632762e+04 -1.75947295e+18  3.31401760e+18  1.29310444e+17
#   3.54832486e+18 -2.10647812e+18]
# 31 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0',
#        'BUILDING_CLASS_AT_PRESENT_B3', 'ZIP_CODE', 'RESIDENTIAL_UNITS'],
#       dtype='object')
# TEST MAE: $90,771,887,396,558,880
#
# Test Data:
# Test MSE: $5306260888729450516652833860965367808.00
# Test RMSE: $2303532263444436992.00
# Test R^2: -60257238064940120908234752.00
#
# Model Intercept and Coefficients
#
# Model intercept 623951.1054612432
#
# Coefficients
# [ 7.37683392e+04  6.90642875e+04 -9.43273091e+04 -1.53081841e+05
#   9.17773746e+04  9.34819032e+04  6.37316222e+04  4.38289941e+04
#   3.64852898e+04 -6.44595676e+17  3.62642504e+17 -9.31915683e+04
#   1.17088489e+04  1.86337166e+18 -1.93331437e+18 -4.85681600e+17
#   3.95334867e+17  3.78475624e+17 -9.78414388e+04  6.46033990e+18
#  -1.92443023e+18 -3.76902914e+14  6.07812408e+04  1.03865294e+05
#  -1.23374069e+04 -1.86337166e+18  3.76635788e+18  6.94915949e+03
#   4.85681600e+17  5.05752436e+18  2.13070241e+17]
# 32 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0',
#        'BUILDING_CLASS_AT_PRESENT_B3', 'ZIP_CODE', 'RESIDENTIAL_UNITS',
#        'COMMERCIAL_UNITS'],
#       dtype='object')
# TEST MAE: $2,643,180,823,185,948
#
# Test Data:
# Test MSE: $4499244731926674265106458674724864.00
# Test RMSE: $67076409652922496.00
# Test R^2: -51092863055410254315520.00
#
# Model Intercept and Coefficients
#
# Model intercept 621439.9469069273
#
# Coefficients
# [ 7.37683392e+04  7.35986344e+04 -8.95381009e+04 -1.41261181e+05
#   9.21776676e+04  9.45892630e+04  6.51298556e+04  4.46031090e+04
#   3.69348662e+04 -1.41079651e+16  4.72914660e+15 -9.28302568e+04
#   1.06273120e+04  5.82046660e+15  1.23693116e+18  3.66692474e+15
#   1.10246151e+16 -1.09093463e+16  3.97127996e+17 -9.46509296e+04
#  -3.36006646e+16 -2.33268693e+18 -2.40147340e+17  6.06563955e+04
#   1.04212864e+05 -1.30830376e+04 -5.82046660e+15  1.15767687e+18
#  -3.66692474e+15 -1.10246151e+16 -1.96038931e+17  3.75641699e+17]
# 33 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0',
#        'BUILDING_CLASS_AT_PRESENT_B3', 'ZIP_CODE', 'RESIDENTIAL_UNITS',
#        'COMMERCIAL_UNITS', 'TOTAL_UNITS'],
#       dtype='object')
# TEST MAE: $5,958,011,642,130,636
#
# Test Data:
# Test MSE: $22860649355494178417508241488478208.00
# Test RMSE: $151197385412229184.00
# Test R^2: -259602688111132572385280.00
#
# Model Intercept and Coefficients
#
# Model intercept 621349.6667390607
#
# Coefficients
# [ 7.45572454e+04  7.62613115e+04 -8.72234569e+04 -1.38072134e+05
#   9.01412256e+04  9.29155828e+04  6.39970320e+04  4.40009583e+04
#   3.56249385e+04 -5.59027784e+16  5.29951609e+16 -9.39863049e+04
#   9.59014483e+03  4.21301293e+15  1.13589387e+18 -9.72860076e+15
#   2.16252919e+16  1.54598564e+16 -1.26323260e+18 -9.18304487e+04
#  -4.08913632e+16 -1.96207678e+18 -5.95480286e+17  5.98237188e+04
#   1.05436261e+05 -3.86238690e+03 -1.46580256e+04 -4.21301293e+15
#   1.16177013e+18  9.72860076e+15 -2.16252919e+16 -5.48380438e+17
#   2.00471726e+18]
# 34 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
# ...
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0',
#        'BUILDING_CLASS_AT_PRESENT_B3', 'ZIP_CODE', 'RESIDENTIAL_UNITS',
#        'COMMERCIAL_UNITS', 'TOTAL_UNITS', 'LAND_SQUARE_FEET',
#        'GROSS_SQUARE_FEET', 'YEAR_BUILT', 'TAX_CLASS_AT_TIME_OF_SALE',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A9',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A1',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A5',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A0',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A2',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A3',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_S1',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A4'],
#       dtype='object')
# TEST MAE: $17,726,582,062,850,070
#
# Test Data:
# Test MSE: $202365222286770430202448578835644416.00
# Test RMSE: $449850222059265472.00
# Test R^2: -2298034271420495255568384.00
#
# Model Intercept and Coefficients
#
# Model intercept 620247.2494549822
#
# Coefficients
# [ 4.88497863e+18  6.67833643e+18  3.94752263e+18  5.89264153e+18
#   2.66915243e+17  4.87855745e+04  6.30498455e+04  4.88902330e+04
#   2.71299437e+04  2.32863178e+04  1.27499601e+17  3.54540426e+17
#  -1.03586095e+05 -5.91346257e+03 -9.85317642e+17 -1.81527066e+18
#  -2.71917088e+18 -2.53702230e+16 -2.17526641e+18 -5.93735994e+16
#   4.56001278e+18  1.24651259e+17 -2.54867422e+17  4.56615730e+17
#  -1.17323885e+17  1.62526512e+17 -1.17323885e+17 -4.96660921e+04
#   1.33887358e+17 -7.48543502e+18 -1.80674753e+18  5.87797913e+04
#   1.00693397e+05  3.55840000e+04 -5.10126801e+17 -8.88021324e+17
#   1.22896728e+17 -8.79408265e+17  9.85060912e+16 -6.26055116e+17
#   3.17639821e+18 -5.27581489e+17 -1.63189202e+17 -2.33219182e+18
#   2.44613048e+18]
# 46 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0',
#        'BUILDING_CLASS_AT_PRESENT_B3', 'ZIP_CODE', 'RESIDENTIAL_UNITS',
#        'COMMERCIAL_UNITS', 'TOTAL_UNITS', 'LAND_SQUARE_FEET',
#        'GROSS_SQUARE_FEET', 'YEAR_BUILT', 'TAX_CLASS_AT_TIME_OF_SALE',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A9',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A1',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A5',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A0',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A2',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A3',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_S1',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A4',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A6'],
#       dtype='object')
# TEST MAE: $52,290,420,689,555,056
#
# Test Data:
# Test MSE: $1760881533743087361759949480704081920.00
# Test RMSE: $1326982115080337920.00
# Test R^2: -19996351481376268317884416.00
#
# Model Intercept and Coefficients
#
# Model intercept 620415.6398259337
#
# Coefficients
# [ 4.09988381e+18  5.60502010e+18  3.31309210e+18  4.94559903e+18
#   2.24017660e+17  4.57051046e+17  3.62315841e+17  1.18431422e+17
#   1.72330821e+17  1.44932145e+17  1.38789770e+17  1.46062156e+18
#  -7.20006401e+17 -1.00569128e+05 -6.01412447e+03 -1.31230653e+18
#  -4.32415909e+17 -3.69427632e+18 -1.90796421e+17 -2.95532555e+18
#  -1.40400652e+17  4.08788104e+18  2.62629861e+17 -1.61340192e+18
#  -1.56332202e+18 -1.59396695e+17 -3.50396788e+18 -1.59396695e+17
#  -6.00282253e+04  1.68962215e+18 -4.25648371e+18 -7.19315287e+18
#   5.83214109e+04  9.80800000e+04  3.60960000e+04 -1.34287072e+16
#  -1.96409534e+18  1.39263808e+18 -6.11304067e+17  1.11624887e+18
#  -4.67242782e+17  4.53301575e+18 -6.19833905e+17  1.24278809e+18
#   2.55898997e+17  6.38534677e+18]
# 47 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0',
#        'BUILDING_CLASS_AT_PRESENT_B3', 'ZIP_CODE', 'RESIDENTIAL_UNITS',
#        'COMMERCIAL_UNITS', 'TOTAL_UNITS', 'LAND_SQUARE_FEET',
#        'GROSS_SQUARE_FEET', 'YEAR_BUILT', 'TAX_CLASS_AT_TIME_OF_SALE',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A9',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A1',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A5',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A0',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A2',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A3',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_S1',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A4',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A6',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A8'],
#       dtype='object')
# TEST MAE: $34,189,007,029,016,532
#
# Test Data:
# Test MSE: $752764001842834437103589854688575488.00
# Test RMSE: $867619733433279232.00
# Test R^2: -8548294291768553779494912.00
#
# Model Intercept and Coefficients
#
# Model intercept 620207.6867665082
#
# Coefficients
# [ 4.31416936e+18  5.89797348e+18  3.48625500e+18  5.20408695e+18
#   2.35726223e+17 -3.28792078e+18 -2.60641736e+18 -8.51968586e+17
#  -1.23970854e+18 -1.04260873e+18 -9.98421888e+17  1.19347328e+18
#  -8.60549469e+17 -1.03779773e+05 -6.33928395e+03  5.22291845e+17
#   6.50541274e+17 -4.90275654e+17  3.29206299e+17 -3.92207848e+17
#   1.98721190e+16  1.02796521e+18 -7.36331810e+17  1.16154778e+17
#  -4.73890902e+17 -2.11538910e+16  7.18038537e+17 -2.11538910e+16
#  -5.90449929e+04 -1.86666165e+18 -2.19760058e+18 -4.66666180e+17
#   5.76319280e+04  9.85280000e+04  3.68640000e+04  0.00000000e+00
#   1.16050732e+17  5.03380811e+17  1.59851631e+18  5.70057287e+16
#   1.28126758e+18  2.72708682e+17  1.69754092e+18  9.08325843e+17
#   6.22960790e+16  6.25635997e+17  1.13698890e+17]
# 48 features:
# Index(['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0',
#        'BUILDING_CLASS_AT_PRESENT_A2', 'BUILDING_CLASS_AT_PRESENT_A3',
#        'BUILDING_CLASS_AT_PRESENT_S1', 'BUILDING_CLASS_AT_PRESENT_A4',
#        'BUILDING_CLASS_AT_PRESENT_A6', 'BUILDING_CLASS_AT_PRESENT_A8',
#        'BUILDING_CLASS_AT_PRESENT_B2', 'BUILDING_CLASS_AT_PRESENT_S0',
#        'BUILDING_CLASS_AT_PRESENT_B3', 'ZIP_CODE', 'RESIDENTIAL_UNITS',
#        'COMMERCIAL_UNITS', 'TOTAL_UNITS', 'LAND_SQUARE_FEET',
#        'GROSS_SQUARE_FEET', 'YEAR_BUILT', 'TAX_CLASS_AT_TIME_OF_SALE',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A9',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A1',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A5',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A0',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A2',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A3',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_S1',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A4',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A6',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_A8',
#        'BUILDING_CLASS_AT_TIME_OF_SALE_S0'],
#       dtype='object')
# TEST MAE: $29,481,764,656,429,336
#
# Test Data:
# Test MSE: $559748344027676433253109162737401856.00
# Test RMSE: $748163313740841216.00
# Test R^2: -6356432510540933536677888.00
#
# Model Intercept and Coefficients
#
# Model intercept 621348.44333531
#
# Coefficients
# [ 3.99016580e+18  5.45502276e+18  3.22442962e+18  4.81324863e+18
#   2.18022668e+17 -2.61107623e+18 -2.06986569e+18 -6.76584100e+17
#  -9.84504714e+17 -8.27979461e+17 -7.92888828e+17 -1.26973649e+18
#   2.31198477e+18 -3.30417440e+17 -1.02061545e+05 -3.52490510e+03
#   1.43385657e+18  7.45070810e+17  5.22592724e+17 -7.26501646e+17
#   4.18060669e+17 -1.97166101e+17 -6.29161453e+17 -1.30195716e+17
#  -1.10370597e+18 -1.02245871e+18  2.25482735e+16 -6.25225159e+18
#   2.25482735e+16 -5.62821129e+04  3.57081113e+18  7.38044306e+17
#  -8.73937241e+18  6.01600000e+04  9.95520000e+04  3.73760000e+04
#   0.00000000e+00 -1.31626016e+18 -5.32493588e+17 -3.18431001e+17
#   7.97650194e+17 -2.55233754e+17  2.51065766e+17  6.27750711e+18
#   1.61880709e+17  1.13658045e+18  1.66152238e+18  8.06623379e+18]
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning:
#
# invalid value encountered in less_equal

# %%
features_df = pd.DataFrame({'MAE':best_mae,'MSE':mse, 'RMSE':rmse, 'R2':r2, 'Intercept':intercept},
                           columns = ['MAE', 'MSE', 'RMSE', 'R2', 'Intercept'])
features_df
# Out:
#              MAE           MSE          RMSE            R2      Intercept
# 0   1.836406e+05  6.912106e+10  2.629088e+05  2.150698e-01  621573.742321
# 1   1.795548e+05  6.710517e+10  2.590467e+05  2.379620e-01  621573.742321
# 2   1.792915e+05  6.684367e+10  2.585414e+05  2.409316e-01  621573.742321
# 3   1.793653e+05  6.689654e+10  2.586437e+05  2.403312e-01  621573.742321
# 4   1.709463e+05  6.244427e+10  2.498885e+05  2.908907e-01  621573.742321
# 5   1.699244e+05  5.769143e+10  2.401904e+05  3.448633e-01  621573.742321
# 6   1.681256e+05  5.635796e+10  2.373983e+05  3.600060e-01  621573.742321
# 7   1.688733e+05  5.712875e+10  2.390162e+05  3.512530e-01  621573.742321
# 8   1.679569e+05  5.597502e+10  2.365904e+05  3.643547e-01  621573.742321
# 9   1.653278e+05  5.359718e+10  2.315106e+05  3.913571e-01  621573.742321
# 10  1.653230e+05  5.398464e+10  2.323460e+05  3.869571e-01  621573.742321
# 11  1.647271e+05  5.375451e+10  2.318502e+05  3.895705e-01  621573.742321
# 12  1.554328e+05  5.092597e+10  2.256678e+05  4.216911e-01  621573.742321
# 13  1.562070e+05  5.097166e+10  2.257691e+05  4.211721e-01  621573.742321
# 14  1.566934e+05  5.115951e+10  2.261847e+05  4.190390e-01  621573.742321
# 15  1.564680e+05  5.102845e+10  2.258948e+05  4.205273e-01  621573.742321
# 16  1.563558e+05  5.091912e+10  2.256527e+05  4.217688e-01  621573.742321
# 17  1.560562e+05  5.071377e+10  2.251972e+05  4.241007e-01  621573.742321
# 18  1.566872e+05  5.122132e+10  2.263213e+05  4.183371e-01  621573.742321
# 19  1.563942e+05  5.088998e+10  2.255881e+05  4.220997e-01  621573.742321
# 20  1.539588e+05  4.941849e+10  2.223027e+05  4.388098e-01  621573.742321
# 21  1.544833e+05  4.965318e+10  2.228299e+05  4.361446e-01  621573.742321
# 22  1.553884e+05  4.965175e+10  2.228267e+05  4.361609e-01  621433.200626
# 23  1.548847e+05  4.980365e+10  2.231673e+05  4.344359e-01  621380.270268
# 24  8.697816e+15  4.871989e+34  2.207258e+17 -5.532570e+23  621184.063548
# 25  1.945546e+14  2.437635e+31  4.937241e+15 -2.768148e+20  621362.962533
# 26  7.034231e+15  3.186538e+34  1.785088e+17 -3.618593e+23  621623.303764
# 27  4.346398e+16  1.216592e+36  1.102992e+18 -1.381547e+25  622651.629010
# 28  6.160919e+16  2.444426e+36  1.563466e+18 -2.775859e+25  622761.880074
# 29  8.112394e+16  4.238224e+36  2.058695e+18 -4.812874e+25  623585.227867
# 30  9.077189e+16  5.306261e+36  2.303532e+18 -6.025724e+25  623951.105461
# 31  2.643181e+15  4.499245e+33  6.707641e+16 -5.109286e+22  621439.946907
# 32  5.958012e+15  2.286065e+34  1.511974e+17 -2.596027e+23  621349.666739
# 33  6.307781e+15  2.562354e+34  1.600735e+17 -2.909777e+23  621408.930800
# 34  6.197664e+15  2.473671e+34  1.572791e+17 -2.809070e+23  621414.765812
# 35  4.974729e+15  1.593766e+34  1.262445e+17 -1.809861e+23  621435.930856
# 36  4.762572e+16  1.460727e+36  1.208605e+18 -1.658783e+25  622963.660825
# 37  7.028929e+16  3.181736e+36  1.783742e+18 -3.613140e+25  623430.583392
# 38  8.466709e+15  4.616524e+34  2.148610e+17 -5.242467e+23  621516.727547
# 39  3.443788e+15  7.637633e+33  8.739355e+16 -8.673201e+22  621389.417412
# 40  2.722514e+15  4.773381e+33  6.908966e+16 -5.420592e+22  621262.447597
# 41  1.757082e+15  1.988246e+33  4.458975e+16 -2.257827e+22  621620.151913
# 42  1.775972e+15  2.031225e+33  4.506911e+16 -2.306634e+22  621786.881067
# 43  3.326431e+16  7.125953e+35  8.441536e+17 -8.092144e+24  623795.618267
# 44  1.772658e+16  2.023652e+35  4.498502e+17 -2.298034e+24  620247.249455
# 45  5.229042e+16  1.760882e+36  1.326982e+18 -1.999635e+25  620415.639826
# 46  3.418901e+16  7.527640e+35  8.676197e+17 -8.548294e+24  620207.686767
# 47  2.948176e+16  5.597483e+35  7.481633e+17 -6.356433e+24  621348.443335

# %% [markdown]
# It seems that 19 features produces the best model.
# ['BOROUGH_3', 'BOROUGH_4', 'BOROUGH_2', 'BOROUGH_5', 'BOROUGH_1',
#        'NEIGHBORHOOD_OTHER', 'NEIGHBORHOOD_FLUSHING-NORTH',
#        'NEIGHBORHOOD_BEDFORD STUYVESANT', 'NEIGHBORHOOD_FOREST HILLS',
#        'NEIGHBORHOOD_BOROUGH PARK', 'NEIGHBORHOOD_ASTORIA',
#        'TAX_CLASS_AT_PRESENT_1', 'TAX_CLASS_AT_PRESENT_1D', 'BLOCK', 'LOT',
#        'BUILDING_CLASS_AT_PRESENT_A9', 'BUILDING_CLASS_AT_PRESENT_A1',
#        'BUILDING_CLASS_AT_PRESENT_A5', 'BUILDING_CLASS_AT_PRESENT_A0']

# %% [markdown]
# #### 7. Fit a ridge regression model with multiple features.

# %%
for alpha in [10**1, 10**2, 10**3, 10**4, 10**5, 10**6 ]:

  #Scale data before doing Ridge Regression
  scaler = StandardScaler()
  X_train_scaled = scaler.fit_transform(X_train)
  X_test_scaled = scaler.transform(X_test)

  #Fit Ridge Regression model
  display(HTML(f'Ridge Regression, with alpha{alpha}'))
  model = Ridge(alpha=alpha)
  model.fit(X_train_scaled, y_train)
  y_pred = model.predict(X_test_selected)

  #Get Test MAE
  mae = mean_absolute_error(y_test, y_pred)
  display(HTML(f'Test Mean Absolute Error: ${mae:,.0f}'))

  #Plot coefficients
  coefficients = pd.Series(model.coef_, X_train.columns)
  plt.figure(figsize = (16,8))
  coefficients.sort_values().plot.barh(color = 'grey')
  plt.xlim(-100000, 100000)
  plt.show()
# Out:
# Ridge Regression, with alpha10
# Test Mean Absolute Error: $155,788
# Ridge Regression, with alpha100
# Test Mean Absolute Error: $155,327
# Ridge Regression, with alpha1000
# Test Mean Absolute Error: $159,318
# Ridge Regression, with alpha10000
# Test Mean Absolute Error: $188,430
# Ridge Regression, with alpha100000
# Test Mean Absolute Error: $207,767
# Ridge Regression, with alpha1000000
# Test Mean Absolute Error: $211,149
